# %% [markdown]
# # (Almost) all the activation functions, illustrated
#
# _This notebook was originally created by Rob Leckeby at Agile Sceintific._
#
# Some activation functions are listed below, then a function to plot them all with their derivatives.
#
# Credit to [Dishashree Gupta](https://www.analyticsvidhya.com/blog/2020/01/fundamentals-deep-learning-activation-functions-when-to-use-them/) for the list of functions.

# %% [markdown]
# ## The sigmoid function
#
# A basic, classical nonlinear function which effectively implements logistic regression in a perceptron.

# %%
import numpy as np


def sigmoid(z, *, derivative=False):
    """
    The sigmoid, or logistic function.
    """
    if derivative:
        # In the backward case, z is really sigmoid(z).
        return z * (1 - z)
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# In a neural network, we have in incoming signal `x`, over which we compute a linear function, `z = wx + b`, where `w` is a set of weights and `b` a set of biases on a given set of neurons.
#
# We don't need `x`, `b` and `w`, we can just focus on what happens to the computed signal `wx + b` when it passed through our nonlinear function. So let's define `z`, a range of possible values for the computed neural signal:

# %%
z = np.linspace(-5, 5, 400)

# %% [markdown]
# Now we can compute the activation `a` and its derivative `a_`. Now, although the symbolic definition of the derivative is `sigmoid(z) * (1 - sigmoid(z)`, we defined it as `z * (1 - z)`, because when we do this calculation inside a neural network, the derivative is being computed on `a`, the result of `sigmoid(z)`. So we pass `a` to the function when we calculate the derivative.

# %%
a = sigmoid(z)
a_ = sigmoid(a, derivative=True)

# %% [markdown]
# Now we can plot these two arrays:

# %%
import matplotlib.pyplot as plt

def plot(z, a, a_):
    fig, axs = plt.subplots(ncols=2, figsize=(15, 4), sharey=True)
    ys, titles = [a, a_], ['Forward function', 'Derivative']
    for ax, y, title in zip(axs, ys, titles):
        ax.set_title(title)
        ax.plot(z, y, lw=3)
        ax.grid(c='k', alpha=0.1)
        ax.axhline(0, c='k', alpha=0.5)
        ax.axvline(0, c='k', alpha=0.5)

plot(z, a, a_)

# %% [markdown]
# We note that the maximum gradient is quite small (0.25), so activations will get attenuated as they pass through a network using this activation function. This is one of the reasons the `tanh` function became popular.

# %% [markdown]
# ## `tanh`
#
# We could use NumPy to compute this, but we can also use the exponential definition:
#
# $$ \tanh x = \frac{e^{2x} - 1} {e^{2x} + 1} $$

# %%
def tanh(z, *, derivative=False):
    """
    The tanh function and its derivative.
    """
    if derivative:
        return 1 - z**2
    return (np.exp(2 * z) - 1) / (np.exp(2 * z) + 1)

# %%
a = tanh(z)
a_ = tanh(a, derivative=True)

# %%
plot(z, a, a_)

# %% [markdown]
# ---
#
# ## Lots more functions!

# %%
def linear(z, *, alpha=1, derivative=False):
    """
    A simple scaling function.
    """
    if derivative:
        return np.ones_like(z) * alpha
    return alpha * z

def binary_step(z, *, derivative=False):
    """
    The Heaviside function.
    """
    if derivative:
        return np.zeros_like(z)
    return 1 * (z > 0)

def relu(z, *, derivative=False):
    """
    Rectified Linear Unit (ReLU) (Hahnloser et al., 2000;
    Jarrett et al., 2009; Nair & Hinton, 2010). Special
    case of LReLU, see below.
    """
    if derivative:
        return 1 * (z > 0)
    return z * (z > 0)

def leaky_relu(z, *, alpha=0.01, derivative=False):
    """
    Leaky ReLU (LReLU). (Maas et al., 2013).
    The ReLU is a special case where alpha = 0.
    """
    if derivative:
        return alpha * (z <= 0) + (z > 0)
    return np.maximum(alpha * z, z)

def elu(z, *, alpha=1, derivative=False):
    """
    Exponential Linear Unit (ELU) (Clevert et al., 2015).
    """
    if derivative:
        return np.where(z < 0, alpha * np.exp(z), 1)
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def swish(z, *, derivative=False):
    """
    SWISH: A self-generated activation function.
    https://arxiv.org/pdf/1710.05941v1.pdf
    Special case of E-Swish, see below.
    """
    if derivative:
        return z * sigmoid(z) + sigmoid(z) * (1 - z * sigmoid(z))
    return z * sigmoid(z)

def eswish(z, *, beta=1, derivative=False):
    """
    Eswish https://arxiv.org/abs/1801.07145
    Eswish is a generalization of Swish,
    multiplied by a parameter beta.
    """
    if derivative:
        return beta * z * sigmoid(z) + sigmoid(z) * (beta - beta * z * sigmoid(z))
    return beta * z * sigmoid(z)

# %% [markdown]
# Let's plot all of these.

# %%
from cycler import cycler

x = np.linspace(-4, 4, 400)
functions = [linear, binary_step, sigmoid, tanh, relu, leaky_relu, elu, eswish]

cyc3 = cycler(color=[u'#1f77b4', u'#ff7f0e', u'#2ca02c'])
props_deriv = {'lw': 2.5, 'ls': '--', 'alpha': 0.67}
props_forward = {'lw': 2.5, 'ls': '-', 'alpha': 1.0}
props_hvlines = {'c': 'k', 'lw': 1.5, 'alpha': 0.3}

fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
fig.suptitle('Activation functions and their derivatives', size=16)

for f, ax in zip(functions, axs.flat):
    ax.set_title(f.__name__.upper().replace('_', ' '))

    for d in (False, True):  # Forward and backward functions.
        props = props_deriv if d else props_forward
        if len(kwargs := f.__kwdefaults__) == 1:
            ax.set_prop_cycle(cycler(color=[u'#1f77b4']))
            y = f(x)
            if d:
                y = f(y, derivative=d)
            ax.plot(x, y, label=None, **props)
        else:
            arg, _ = kwargs.keys()
            vals = [1, 1.5, 2] if f is eswish else [0.05, 0.5, 1]
            ax.set_prop_cycle(cyc3)
            for v in vals:
                kwargs.update({arg: v, 'derivative': d})
                y = f(x, **kwargs)
                label = f"{arg}: {v}" if not d else None
                ax.plot(x, y, label=label, **props)
            ax.legend(loc=4)

    ax.grid()
    ax.axhline(0, -3, 3, **props_hvlines)
    ax.axvline(0, -3, 3, **props_hvlines)
    ax.set_xlim(-3, 3); ax.set_ylim(-3, 3)

plt.subplots_adjust(hspace=0.4)
plt.show()

# %% [markdown]
# ---
#
# &copy; Matt Hall 2024 and Rob Leckenby 2021, licenced CC BY, please share and re-use

# %% [markdown]
# # **Activation Functions in Deep Learning**

# %% [markdown]
# ## **What are Activation Functions?**
# In artificial neural networks, each neuron forms a weighted sum of its inputs and passes the resulting scalar value through a function referred to as an activation function or transfer function. If a neuron has n inputs $x_1, x_2, ..., x_n$ then the output of a neuron is:
# $$a = g(w_1x_1 + w_2x_2 + w_3x_3 + ... + w_nx_n + b)$$
# The function $g$ is referred to as the activation function. If the function $g$ is taken as the linear function $g(z) = z$ then the neuron performs linear regression or classification. In general $g$ is taken to be a nonlinear function to do nonlinear regression and solve classification problems that are not linearly separable. When $g$ is taken to be a sigmoidal or 's' shaped function varying from 0 to 1 or -1 to 1, the output value of the neuron can be interpreted as a YES/NO answer or binary decision. However saturating activation function can cause the vanishing gradient problem in deep networks. Replacing saturating sigmoidal activation functions with activation functions like ReLU that have larger derivative values allowed deeper networks to be trained for the first time. Non-monotonic and oscillating activation functions that significantly outperform ReLU have since been found. In particular oscillating activation functions improve gradient flow, speedup training and allow single neurons to learn the XOR function like certain human cerebral neurons.
#
# <img src="https://miro.medium.com/v2/resize:fit:1170/1*abHGVMc8bTFVFSvB6ZYaBg.png" width="40%">

# %% [markdown]
# ## **Why Activation Functions are needed?**
# Activation functions are essential in neural networks for the following reasons:
#
# 1. **Introduce Non-Linearity**: They allow networks to learn complex, non-linear relationships in data, which linear models can't capture.
#
# 2. **Enable Deep Learning**: They help in learning hierarchical feature representations, allowing deeper layers to capture more abstract patterns.
#
# 3. **Universal Approximation**: With activation functions, networks can approximate any continuous function, as per the Universal Approximation Theorem.
#
# 4. **Gradient-Based Optimization**: They provide the necessary gradients for training via backpropagation, making learning possible and efficient.
#
# 5. **Biological Inspiration**: They mimic the non-linear activation of biological neurons, adding biological plausibility to artificial models.
#
# 6. **Output Characteristics**: Different activation functions offer various output ranges, suited for specific tasks like classification.

# %% [markdown]
# ### **Code Example**

# %% [markdown]
# #### **Import Required Libraries**

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.11/dist-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from mlxtend.plotting import plot_decision_regions

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["font.family"] = "DeJavu Serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %% [markdown]
# #### **Make a Dataset**

# %%
# Generate a classification dataset
X, y = make_classification(
    n_samples=200,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    class_sep=1,
    random_state=32)

# Plot the data
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y);

# %% [markdown]
# #### **Neural Network with Linear Activation in the Hidden Layers**

# %%
# Build a neural network with linear activation used in the hidden layers
model = Sequential()

model.add(Dense(128, activation="linear", input_dim=2))
model.add(Dense(128, activation="linear"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X, y, epochs=500, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7979 - loss: 0.5313 - val_accuracy: 0.8000 - val_loss: 0.4779
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8320 - loss: 0.5279 - val_accuracy: 0.8000 - val_loss: 0.5318
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8735 - loss: 0.3729 - val_accuracy: 0.8000 - val_loss: 0.3652
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8382 - loss: 0.3804 - val_accuracy: 0.8000 - val_loss: 0.3546
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8538 - loss: 0.3756 - val_accuracy: 0.7750 - val_loss: 0.4531
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7941 - loss: 0.4124 - val_accuracy: 0.7750 - val_loss: 0.4014
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8386 - loss: 0.3879 - val_accuracy: 0.7750 - val_loss: 0.3774
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8159 - loss: 0.3880 - val_accuracy: 0.7750 - val_loss: 0.3794
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8479 - loss: 0.3607 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8515 - loss: 0.3468 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8236 - loss: 0.3823 - val_accuracy: 0.7750 - val_loss: 0.3859
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8396 - loss: 0.3674 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8084 - loss: 0.4230 - val_accuracy: 0.7750 - val_loss: 0.3745
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.8444 - loss: 0.3553 - val_accuracy: 0.7750 - val_loss: 0.3908
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8197 - loss: 0.3849 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8258 - loss: 0.3860 - val_accuracy: 0.7750 - val_loss: 0.3767
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8526 - loss: 0.3274 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8115 - loss: 0.4138 - val_accuracy: 0.7750 - val_loss: 0.3812
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8422 - loss: 0.3950 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8375 - loss: 0.3861 - val_accuracy: 0.7750 - val_loss: 0.3800
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8476 - loss: 0.3854 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8298 - loss: 0.3787 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8309 - loss: 0.3689 - val_accuracy: 0.7750 - val_loss: 0.3999
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8734 - loss: 0.3245 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8214 - loss: 0.4036 - val_accuracy: 0.7750 - val_loss: 0.3755
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8210 - loss: 0.4136 - val_accuracy: 0.7750 - val_loss: 0.3853
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8015 - loss: 0.4265 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7963 - loss: 0.4156 - val_accuracy: 0.7750 - val_loss: 0.3895
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8042 - loss: 0.3944 - val_accuracy: 0.7750 - val_loss: 0.3730
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8345 - loss: 0.3876 - val_accuracy: 0.7750 - val_loss: 0.3740
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.4002 - val_accuracy: 0.7750 - val_loss: 0.3886
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8122 - loss: 0.4085 - val_accuracy: 0.7750 - val_loss: 0.4002
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8287 - loss: 0.3934 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8207 - loss: 0.3931 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8561 - loss: 0.3547 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8406 - loss: 0.3240 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8093 - loss: 0.3997 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8331 - loss: 0.4170 - val_accuracy: 0.7750 - val_loss: 0.3997
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8292 - loss: 0.3949 - val_accuracy: 0.7750 - val_loss: 0.3937
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8435 - loss: 0.3998 - val_accuracy: 0.7750 - val_loss: 0.3691
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8081 - loss: 0.4242 - val_accuracy: 0.7750 - val_loss: 0.3744
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8409 - loss: 0.3924 - val_accuracy: 0.7750 - val_loss: 0.3958
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8642 - loss: 0.3493 - val_accuracy: 0.7750 - val_loss: 0.3995
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8240 - loss: 0.4015 - val_accuracy: 0.7750 - val_loss: 0.3794
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8667 - loss: 0.3522 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8366 - loss: 0.3632 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8055 - loss: 0.4286 - val_accuracy: 0.7750 - val_loss: 0.3752
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8449 - loss: 0.3596 - val_accuracy: 0.7750 - val_loss: 0.4076
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8193 - loss: 0.3906 - val_accuracy: 0.7750 - val_loss: 0.3752
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8011 - loss: 0.4172 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7885 - loss: 0.4499 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.3791 - val_accuracy: 0.7750 - val_loss: 0.4039
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7998 - loss: 0.4576 - val_accuracy: 0.7750 - val_loss: 0.3723
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8445 - loss: 0.3810 - val_accuracy: 0.7750 - val_loss: 0.3813
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8154 - loss: 0.4263 - val_accuracy: 0.7750 - val_loss: 0.3937
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7907 - loss: 0.4225 - val_accuracy: 0.7750 - val_loss: 0.4031
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8562 - loss: 0.3652 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8180 - loss: 0.3687 - val_accuracy: 0.7750 - val_loss: 0.3758
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8548 - loss: 0.3290 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8318 - loss: 0.3825 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8132 - loss: 0.4354 - val_accuracy: 0.7750 - val_loss: 0.3786
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8046 - loss: 0.4028 - val_accuracy: 0.7750 - val_loss: 0.4024
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8089 - loss: 0.4378 - val_accuracy: 0.7750 - val_loss: 0.3910
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8539 - loss: 0.3975 - val_accuracy: 0.7750 - val_loss: 0.3921
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8431 - loss: 0.3464 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8311 - loss: 0.3564 - val_accuracy: 0.7750 - val_loss: 0.3747
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8362 - loss: 0.3978 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7990 - loss: 0.4036 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8414 - loss: 0.3837 - val_accuracy: 0.7750 - val_loss: 0.3884
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8197 - loss: 0.3614 - val_accuracy: 0.7750 - val_loss: 0.3934
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8379 - loss: 0.3576 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8401 - loss: 0.3769 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8162 - loss: 0.3740 - val_accuracy: 0.7750 - val_loss: 0.3895
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8241 - loss: 0.3655 - val_accuracy: 0.7750 - val_loss: 0.3801
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8401 - loss: 0.3898 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7759 - loss: 0.4437 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8284 - loss: 0.3582 - val_accuracy: 0.7750 - val_loss: 0.3938
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8194 - loss: 0.3596 - val_accuracy: 0.8000 - val_loss: 0.3716
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8595 - loss: 0.3612 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8640 - loss: 0.3362 - val_accuracy: 0.7750 - val_loss: 0.3958
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7993 - loss: 0.4171 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8266 - loss: 0.4078 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8140 - loss: 0.4213 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8457 - loss: 0.3791 - val_accuracy: 0.7750 - val_loss: 0.3873
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8453 - loss: 0.3583 - val_accuracy: 0.8000 - val_loss: 0.3803
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8359 - loss: 0.3619 - val_accuracy: 0.7750 - val_loss: 0.3863
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8122 - loss: 0.4117 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8526 - loss: 0.3790 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8141 - loss: 0.3988 - val_accuracy: 0.7750 - val_loss: 0.3882
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8228 - loss: 0.3879 - val_accuracy: 0.7750 - val_loss: 0.3763
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.3728 - val_accuracy: 0.7750 - val_loss: 0.3882
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8032 - loss: 0.4048 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7907 - loss: 0.4241 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8301 - loss: 0.3803 - val_accuracy: 0.7750 - val_loss: 0.3976
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8140 - loss: 0.4679 - val_accuracy: 0.7750 - val_loss: 0.3886
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8288 - loss: 0.3607 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7954 - loss: 0.4580 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8337 - loss: 0.3675 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8392 - loss: 0.3939 - val_accuracy: 0.7750 - val_loss: 0.3947
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8219 - loss: 0.3979 - val_accuracy: 0.7750 - val_loss: 0.3934
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8391 - loss: 0.3731 - val_accuracy: 0.7750 - val_loss: 0.3789
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8389 - loss: 0.3635 - val_accuracy: 0.7750 - val_loss: 0.3886
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8337 - loss: 0.3774 - val_accuracy: 0.7750 - val_loss: 0.3790
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8361 - loss: 0.3807 - val_accuracy: 0.7750 - val_loss: 0.3759
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8414 - loss: 0.3725 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8045 - loss: 0.4009 - val_accuracy: 0.7750 - val_loss: 0.3771
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8084 - loss: 0.4014 - val_accuracy: 0.7750 - val_loss: 0.3877
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8210 - loss: 0.4074 - val_accuracy: 0.7750 - val_loss: 0.3895
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8132 - loss: 0.4163 - val_accuracy: 0.7750 - val_loss: 0.3886
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8010 - loss: 0.4248 - val_accuracy: 0.7750 - val_loss: 0.3758
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7780 - loss: 0.4808 - val_accuracy: 0.7750 - val_loss: 0.3794
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8111 - loss: 0.4303 - val_accuracy: 0.7750 - val_loss: 0.3958
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8479 - loss: 0.3455 - val_accuracy: 0.7750 - val_loss: 0.4117
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8188 - loss: 0.4366 - val_accuracy: 0.7750 - val_loss: 0.3800
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8062 - loss: 0.3985 - val_accuracy: 0.7750 - val_loss: 0.3839
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8119 - loss: 0.4333 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8571 - loss: 0.3225 - val_accuracy: 0.7750 - val_loss: 0.3975
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8596 - loss: 0.3550 - val_accuracy: 0.7750 - val_loss: 0.3885
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8167 - loss: 0.4233 - val_accuracy: 0.7750 - val_loss: 0.3812
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8466 - loss: 0.3894 - val_accuracy: 0.7750 - val_loss: 0.3930
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8401 - loss: 0.3939 - val_accuracy: 0.7750 - val_loss: 0.3897
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8332 - loss: 0.3551 - val_accuracy: 0.7750 - val_loss: 0.3868
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7955 - loss: 0.4004 - val_accuracy: 0.7750 - val_loss: 0.3724
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8384 - loss: 0.3876 - val_accuracy: 0.7750 - val_loss: 0.3800
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8106 - loss: 0.4287 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8162 - loss: 0.4288 - val_accuracy: 0.7750 - val_loss: 0.3932
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8210 - loss: 0.3738 - val_accuracy: 0.7750 - val_loss: 0.4056
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7956 - loss: 0.4204 - val_accuracy: 0.8000 - val_loss: 0.3671
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8339 - loss: 0.3904 - val_accuracy: 0.7750 - val_loss: 0.3750
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8194 - loss: 0.4084 - val_accuracy: 0.7750 - val_loss: 0.3902
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8080 - loss: 0.4454 - val_accuracy: 0.7750 - val_loss: 0.3796
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8331 - loss: 0.3816 - val_accuracy: 0.7750 - val_loss: 0.3942
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8414 - loss: 0.3548 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8206 - loss: 0.4128 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8042 - loss: 0.3979 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8492 - loss: 0.3651 - val_accuracy: 0.7750 - val_loss: 0.4024
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8322 - loss: 0.4041 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8084 - loss: 0.4289 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - loss: 0.4248 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8379 - loss: 0.3655 - val_accuracy: 0.7750 - val_loss: 0.3970
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8176 - loss: 0.3952 - val_accuracy: 0.7750 - val_loss: 0.3743
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8353 - loss: 0.3938 - val_accuracy: 0.7750 - val_loss: 0.3917
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8188 - loss: 0.4121 - val_accuracy: 0.7750 - val_loss: 0.3957
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8322 - loss: 0.4220 - val_accuracy: 0.7750 - val_loss: 0.3817
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8162 - loss: 0.4120 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8415 - loss: 0.3913 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8175 - loss: 0.4086 - val_accuracy: 0.7750 - val_loss: 0.3868
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7915 - loss: 0.4263 - val_accuracy: 0.7750 - val_loss: 0.3912
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8617 - loss: 0.3610 - val_accuracy: 0.7750 - val_loss: 0.3881
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8570 - loss: 0.3692 - val_accuracy: 0.7750 - val_loss: 0.3780
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8427 - loss: 0.3722 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8562 - loss: 0.3384 - val_accuracy: 0.7750 - val_loss: 0.3955
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8076 - loss: 0.4039 - val_accuracy: 0.7750 - val_loss: 0.3749
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8314 - loss: 0.3797 - val_accuracy: 0.7750 - val_loss: 0.3786
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7937 - loss: 0.3889 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8249 - loss: 0.3925 - val_accuracy: 0.7750 - val_loss: 0.3927
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7967 - loss: 0.4101 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8531 - loss: 0.3345 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8185 - loss: 0.4176 - val_accuracy: 0.7750 - val_loss: 0.3851
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8197 - loss: 0.3874 - val_accuracy: 0.7750 - val_loss: 0.3829
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8554 - loss: 0.3471 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8155 - loss: 0.3986 - val_accuracy: 0.7750 - val_loss: 0.3828
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7976 - loss: 0.4434 - val_accuracy: 0.7750 - val_loss: 0.3760
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8372 - loss: 0.3675 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8484 - loss: 0.3829 - val_accuracy: 0.7750 - val_loss: 0.3930
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8363 - loss: 0.3742 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8328 - loss: 0.3826 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8041 - loss: 0.3996 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8115 - loss: 0.4254 - val_accuracy: 0.7750 - val_loss: 0.3836
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7920 - loss: 0.4339 - val_accuracy: 0.7750 - val_loss: 0.3806
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7734 - loss: 0.4733 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8016 - loss: 0.4286 - val_accuracy: 0.7750 - val_loss: 0.3936
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8002 - loss: 0.4065 - val_accuracy: 0.7750 - val_loss: 0.3963
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8271 - loss: 0.3742 - val_accuracy: 0.7750 - val_loss: 0.3767
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8310 - loss: 0.3865 - val_accuracy: 0.7750 - val_loss: 0.3767
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8045 - loss: 0.4205 - val_accuracy: 0.7750 - val_loss: 0.3855
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8349 - loss: 0.3665 - val_accuracy: 0.7750 - val_loss: 0.3913
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8258 - loss: 0.3680 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8371 - loss: 0.3571 - val_accuracy: 0.7750 - val_loss: 0.3818
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8106 - loss: 0.4057 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8163 - loss: 0.3844 - val_accuracy: 0.7750 - val_loss: 0.3805
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8076 - loss: 0.4432 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8431 - loss: 0.3809 - val_accuracy: 0.7750 - val_loss: 0.3975
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8366 - loss: 0.3692 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8514 - loss: 0.3674 - val_accuracy: 0.7750 - val_loss: 0.3811
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8296 - loss: 0.3700 - val_accuracy: 0.7750 - val_loss: 0.3776
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8054 - loss: 0.4157 - val_accuracy: 0.7750 - val_loss: 0.3781
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8270 - loss: 0.3775 - val_accuracy: 0.7750 - val_loss: 0.3814
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8249 - loss: 0.3718 - val_accuracy: 0.7750 - val_loss: 0.3935
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8101 - loss: 0.4224 - val_accuracy: 0.7750 - val_loss: 0.3888
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8153 - loss: 0.4290 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.3897 - val_accuracy: 0.7750 - val_loss: 0.3923
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7880 - loss: 0.4633 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7919 - loss: 0.4273 - val_accuracy: 0.7750 - val_loss: 0.3809
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8218 - loss: 0.3976 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7894 - loss: 0.4534 - val_accuracy: 0.7750 - val_loss: 0.3859
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8484 - loss: 0.3845 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8449 - loss: 0.3598 - val_accuracy: 0.7750 - val_loss: 0.3927
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8145 - loss: 0.4201 - val_accuracy: 0.7750 - val_loss: 0.3853
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8024 - loss: 0.3923 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.3513 - val_accuracy: 0.7750 - val_loss: 0.3878
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8363 - loss: 0.3602 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8358 - loss: 0.3523 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8224 - loss: 0.3888 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8544 - loss: 0.3500 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8306 - loss: 0.3625 - val_accuracy: 0.7750 - val_loss: 0.3873
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8180 - loss: 0.3930 - val_accuracy: 0.7750 - val_loss: 0.3882
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8128 - loss: 0.3923 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7876 - loss: 0.4321 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8324 - loss: 0.3798 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8185 - loss: 0.3870 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.3532 - val_accuracy: 0.7750 - val_loss: 0.3878
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7929 - loss: 0.3974 - val_accuracy: 0.7750 - val_loss: 0.3806
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8224 - loss: 0.3905 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8349 - loss: 0.3634 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8244 - loss: 0.4171 - val_accuracy: 0.7750 - val_loss: 0.3923
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8239 - loss: 0.3827 - val_accuracy: 0.7750 - val_loss: 0.3958
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8401 - loss: 0.4095 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8115 - loss: 0.3996 - val_accuracy: 0.7750 - val_loss: 0.3737
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8341 - loss: 0.4156 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8500 - loss: 0.3681 - val_accuracy: 0.7750 - val_loss: 0.3934
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8097 - loss: 0.3957 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8579 - loss: 0.3544 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8436 - loss: 0.3533 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8193 - loss: 0.4042 - val_accuracy: 0.7750 - val_loss: 0.3771
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8210 - loss: 0.3994 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8211 - loss: 0.4084 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8168 - loss: 0.4080 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8076 - loss: 0.3915 - val_accuracy: 0.7750 - val_loss: 0.3909
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8687 - loss: 0.3505 - val_accuracy: 0.7750 - val_loss: 0.3989
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7993 - loss: 0.4104 - val_accuracy: 0.7750 - val_loss: 0.3854
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8440 - loss: 0.3620 - val_accuracy: 0.7750 - val_loss: 0.3805
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8029 - loss: 0.4158 - val_accuracy: 0.7750 - val_loss: 0.3750
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8171 - loss: 0.4191 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8402 - loss: 0.3600 - val_accuracy: 0.7750 - val_loss: 0.3926
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8049 - loss: 0.4234 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8110 - loss: 0.4263 - val_accuracy: 0.7750 - val_loss: 0.3866
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8146 - loss: 0.3961 - val_accuracy: 0.7750 - val_loss: 0.3857
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8055 - loss: 0.4154 - val_accuracy: 0.7750 - val_loss: 0.3883
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8080 - loss: 0.4177 - val_accuracy: 0.7750 - val_loss: 0.3918
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8206 - loss: 0.3903 - val_accuracy: 0.7750 - val_loss: 0.3856
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7655 - loss: 0.4679 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8418 - loss: 0.3625 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8206 - loss: 0.4224 - val_accuracy: 0.7750 - val_loss: 0.3908
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8366 - loss: 0.3481 - val_accuracy: 0.7750 - val_loss: 0.3912
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8129 - loss: 0.4079 - val_accuracy: 0.7750 - val_loss: 0.3697
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8155 - loss: 0.3555 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8224 - loss: 0.3677 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7898 - loss: 0.4243 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8227 - loss: 0.3929 - val_accuracy: 0.7750 - val_loss: 0.3917
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8310 - loss: 0.4052 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8414 - loss: 0.3800 - val_accuracy: 0.7750 - val_loss: 0.3932
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8315 - loss: 0.3429 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8423 - loss: 0.3636 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8348 - loss: 0.3966 - val_accuracy: 0.7750 - val_loss: 0.3808
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8188 - loss: 0.3802 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8470 - loss: 0.3572 - val_accuracy: 0.7750 - val_loss: 0.3942
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8096 - loss: 0.4623 - val_accuracy: 0.7750 - val_loss: 0.3741
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8237 - loss: 0.3848 - val_accuracy: 0.7750 - val_loss: 0.3762
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7998 - loss: 0.3996 - val_accuracy: 0.7750 - val_loss: 0.3954
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8375 - loss: 0.4216 - val_accuracy: 0.7750 - val_loss: 0.3854
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8457 - loss: 0.3660 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8180 - loss: 0.4113 - val_accuracy: 0.7750 - val_loss: 0.3832
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8049 - loss: 0.4296 - val_accuracy: 0.7750 - val_loss: 0.3756
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8220 - loss: 0.3864 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8262 - loss: 0.3924 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8410 - loss: 0.3711 - val_accuracy: 0.7750 - val_loss: 0.3894
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8310 - loss: 0.3825 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8159 - loss: 0.4176 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8378 - loss: 0.3998 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8310 - loss: 0.3699 - val_accuracy: 0.7750 - val_loss: 0.3986
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8444 - loss: 0.3363 - val_accuracy: 0.7750 - val_loss: 0.3853
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8271 - loss: 0.3826 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8236 - loss: 0.4046 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8475 - loss: 0.3670 - val_accuracy: 0.7750 - val_loss: 0.3929
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8301 - loss: 0.3784 - val_accuracy: 0.7750 - val_loss: 0.3859
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8337 - loss: 0.3549 - val_accuracy: 0.7750 - val_loss: 0.3789
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8170 - loss: 0.4142 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8744 - loss: 0.3238 - val_accuracy: 0.7750 - val_loss: 0.3976
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7989 - loss: 0.4012 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8201 - loss: 0.4188 - val_accuracy: 0.7750 - val_loss: 0.3854
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8224 - loss: 0.3991 - val_accuracy: 0.7750 - val_loss: 0.3913
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8224 - loss: 0.3774 - val_accuracy: 0.7750 - val_loss: 0.3881
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8214 - loss: 0.3916 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8306 - loss: 0.3751 - val_accuracy: 0.7750 - val_loss: 0.3952
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8241 - loss: 0.3842 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8288 - loss: 0.3609 - val_accuracy: 0.7750 - val_loss: 0.3772
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8144 - loss: 0.4377 - val_accuracy: 0.7750 - val_loss: 0.3755
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8293 - loss: 0.3550 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8128 - loss: 0.4081 - val_accuracy: 0.7750 - val_loss: 0.3796
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8436 - loss: 0.3805 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7932 - loss: 0.4501 - val_accuracy: 0.7750 - val_loss: 0.3911
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8497 - loss: 0.3408 - val_accuracy: 0.7750 - val_loss: 0.3946
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8328 - loss: 0.3773 - val_accuracy: 0.7750 - val_loss: 0.3762
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8570 - loss: 0.3514 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8141 - loss: 0.3753 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8232 - loss: 0.3976 - val_accuracy: 0.7750 - val_loss: 0.3832
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8367 - loss: 0.3901 - val_accuracy: 0.7750 - val_loss: 0.3818
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7855 - loss: 0.4509 - val_accuracy: 0.7750 - val_loss: 0.3762
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8410 - loss: 0.3709 - val_accuracy: 0.7750 - val_loss: 0.3847
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8085 - loss: 0.3785 - val_accuracy: 0.7750 - val_loss: 0.3847
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8102 - loss: 0.3946 - val_accuracy: 0.7750 - val_loss: 0.3816
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8449 - loss: 0.3576 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8093 - loss: 0.4251 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8464 - loss: 0.3836 - val_accuracy: 0.7750 - val_loss: 0.4005
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8348 - loss: 0.4003 - val_accuracy: 0.7750 - val_loss: 0.3864
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8493 - loss: 0.3416 - val_accuracy: 0.8000 - val_loss: 0.3746
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7989 - loss: 0.3935 - val_accuracy: 0.7750 - val_loss: 0.3794
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8341 - loss: 0.3599 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8007 - loss: 0.4137 - val_accuracy: 0.7750 - val_loss: 0.3999
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8329 - loss: 0.3467 - val_accuracy: 0.7750 - val_loss: 0.3817
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8124 - loss: 0.4161 - val_accuracy: 0.7750 - val_loss: 0.3987
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8144 - loss: 0.3903 - val_accuracy: 0.8000 - val_loss: 0.3814
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8119 - loss: 0.4485 - val_accuracy: 0.7750 - val_loss: 0.3955
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8408 - loss: 0.3674 - val_accuracy: 0.8000 - val_loss: 0.3893
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8479 - loss: 0.3960 - val_accuracy: 0.8000 - val_loss: 0.3663
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8075 - loss: 0.4218 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8110 - loss: 0.3955 - val_accuracy: 0.7750 - val_loss: 0.4039
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8214 - loss: 0.4143 - val_accuracy: 0.7750 - val_loss: 0.3731
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8145 - loss: 0.4002 - val_accuracy: 0.7750 - val_loss: 0.3715
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8167 - loss: 0.3919 - val_accuracy: 0.7750 - val_loss: 0.3878
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8444 - loss: 0.3875 - val_accuracy: 0.7750 - val_loss: 0.3968
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7985 - loss: 0.3952 - val_accuracy: 0.7750 - val_loss: 0.3754
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8108 - loss: 0.3955 - val_accuracy: 0.7750 - val_loss: 0.3791
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8245 - loss: 0.4088 - val_accuracy: 0.7750 - val_loss: 0.3887
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8470 - loss: 0.3867 - val_accuracy: 0.7750 - val_loss: 0.3962
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8321 - loss: 0.3966 - val_accuracy: 0.7750 - val_loss: 0.3857
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8497 - loss: 0.3745 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8145 - loss: 0.4451 - val_accuracy: 0.7750 - val_loss: 0.3734
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8352 - loss: 0.3772 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.3802 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8168 - loss: 0.3717 - val_accuracy: 0.7750 - val_loss: 0.3915
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8366 - loss: 0.3672 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8010 - loss: 0.4094 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8197 - loss: 0.3920 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8041 - loss: 0.4212 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8315 - loss: 0.3784 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8063 - loss: 0.4008 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8679 - loss: 0.3368 - val_accuracy: 0.7750 - val_loss: 0.3877
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8249 - loss: 0.4084 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8272 - loss: 0.3668 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8033 - loss: 0.4104 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8003 - loss: 0.3785 - val_accuracy: 0.7750 - val_loss: 0.3907
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8653 - loss: 0.3604 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8184 - loss: 0.3719 - val_accuracy: 0.7750 - val_loss: 0.3813
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8375 - loss: 0.3627 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8062 - loss: 0.3971 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8337 - loss: 0.3704 - val_accuracy: 0.7750 - val_loss: 0.3822
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8036 - loss: 0.4437 - val_accuracy: 0.7750 - val_loss: 0.3750
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8470 - loss: 0.3700 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8219 - loss: 0.3813 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8285 - loss: 0.3532 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8209 - loss: 0.4256 - val_accuracy: 0.7750 - val_loss: 0.3864
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8332 - loss: 0.3828 - val_accuracy: 0.7750 - val_loss: 0.3896
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8062 - loss: 0.3967 - val_accuracy: 0.8000 - val_loss: 0.3733
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8179 - loss: 0.4000 - val_accuracy: 0.7750 - val_loss: 0.3746
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8284 - loss: 0.4037 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8123 - loss: 0.3929 - val_accuracy: 0.7750 - val_loss: 0.3966
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8040 - loss: 0.4432 - val_accuracy: 0.7750 - val_loss: 0.3903
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8327 - loss: 0.3893 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8097 - loss: 0.4157 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8280 - loss: 0.3551 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8119 - loss: 0.3814 - val_accuracy: 0.7750 - val_loss: 0.3896
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8002 - loss: 0.4323 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8384 - loss: 0.4196 - val_accuracy: 0.7750 - val_loss: 0.3851
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8249 - loss: 0.3701 - val_accuracy: 0.7750 - val_loss: 0.3953
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8328 - loss: 0.3536 - val_accuracy: 0.7750 - val_loss: 0.3859
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8189 - loss: 0.3954 - val_accuracy: 0.7750 - val_loss: 0.3775
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8133 - loss: 0.4216 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8275 - loss: 0.3881 - val_accuracy: 0.7750 - val_loss: 0.3941
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8358 - loss: 0.3723 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8424 - loss: 0.3518 - val_accuracy: 0.7750 - val_loss: 0.3858
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8288 - loss: 0.3946 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8375 - loss: 0.3622 - val_accuracy: 0.7750 - val_loss: 0.3847
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8311 - loss: 0.3674 - val_accuracy: 0.7750 - val_loss: 0.3867
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8123 - loss: 0.3663 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8211 - loss: 0.3595 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8418 - loss: 0.4187 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8097 - loss: 0.4118 - val_accuracy: 0.7750 - val_loss: 0.3921
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8098 - loss: 0.3934 - val_accuracy: 0.7750 - val_loss: 0.3822
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8631 - loss: 0.3318 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8050 - loss: 0.4119 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8097 - loss: 0.4423 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8062 - loss: 0.3747 - val_accuracy: 0.7750 - val_loss: 0.3988
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8092 - loss: 0.4173 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8037 - loss: 0.4012 - val_accuracy: 0.7750 - val_loss: 0.3769
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8505 - loss: 0.3645 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8228 - loss: 0.3715 - val_accuracy: 0.7750 - val_loss: 0.3796
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8232 - loss: 0.3893 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8045 - loss: 0.4109 - val_accuracy: 0.7750 - val_loss: 0.3797
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8193 - loss: 0.3768 - val_accuracy: 0.7750 - val_loss: 0.3940
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8227 - loss: 0.3671 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8288 - loss: 0.3646 - val_accuracy: 0.7750 - val_loss: 0.3806
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8319 - loss: 0.3661 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8566 - loss: 0.3361 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8266 - loss: 0.3982 - val_accuracy: 0.7750 - val_loss: 0.3902
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8149 - loss: 0.4002 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7989 - loss: 0.4243 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8079 - loss: 0.3967 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8453 - loss: 0.3559 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7998 - loss: 0.4485 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8232 - loss: 0.4220 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8276 - loss: 0.3719 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8350 - loss: 0.3617 - val_accuracy: 0.7750 - val_loss: 0.3915
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8414 - loss: 0.3621 - val_accuracy: 0.7750 - val_loss: 0.3855
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8431 - loss: 0.3693 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8462 - loss: 0.3725 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8285 - loss: 0.3672 - val_accuracy: 0.7750 - val_loss: 0.3797
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8067 - loss: 0.3989 - val_accuracy: 0.7750 - val_loss: 0.3796
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8280 - loss: 0.3826 - val_accuracy: 0.7750 - val_loss: 0.3809
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7981 - loss: 0.3809 - val_accuracy: 0.7750 - val_loss: 0.3917
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8322 - loss: 0.4241 - val_accuracy: 0.7750 - val_loss: 0.3880
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8423 - loss: 0.3467 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8258 - loss: 0.3902 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8227 - loss: 0.4023 - val_accuracy: 0.7750 - val_loss: 0.3767
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8181 - loss: 0.4136 - val_accuracy: 0.7750 - val_loss: 0.3808
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8280 - loss: 0.3968 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8093 - loss: 0.3775 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8314 - loss: 0.4058 - val_accuracy: 0.7750 - val_loss: 0.3832
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8098 - loss: 0.3788 - val_accuracy: 0.7750 - val_loss: 0.3810
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8085 - loss: 0.4031 - val_accuracy: 0.7750 - val_loss: 0.3797
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8071 - loss: 0.4020 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8418 - loss: 0.3750 - val_accuracy: 0.7750 - val_loss: 0.3922
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8557 - loss: 0.3547 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8097 - loss: 0.4133 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8271 - loss: 0.3876 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8306 - loss: 0.3761 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.4118 - val_accuracy: 0.7750 - val_loss: 0.3800
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8418 - loss: 0.4048 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8188 - loss: 0.3837 - val_accuracy: 0.7750 - val_loss: 0.3829
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8288 - loss: 0.3958 - val_accuracy: 0.7750 - val_loss: 0.3860
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8310 - loss: 0.3647 - val_accuracy: 0.7750 - val_loss: 0.3887
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8440 - loss: 0.3759 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8123 - loss: 0.4229 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8085 - loss: 0.3720 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7827 - loss: 0.4073 - val_accuracy: 0.7750 - val_loss: 0.3772
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8253 - loss: 0.4155 - val_accuracy: 0.7750 - val_loss: 0.3815
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8259 - loss: 0.3965 - val_accuracy: 0.7750 - val_loss: 0.3882
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8115 - loss: 0.4455 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8262 - loss: 0.3617 - val_accuracy: 0.7750 - val_loss: 0.3946
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8457 - loss: 0.3779 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8141 - loss: 0.4215 - val_accuracy: 0.7750 - val_loss: 0.3763
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8133 - loss: 0.4015 - val_accuracy: 0.7750 - val_loss: 0.3813
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8129 - loss: 0.3786 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8384 - loss: 0.3961 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8514 - loss: 0.3624 - val_accuracy: 0.7750 - val_loss: 0.3919
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8475 - loss: 0.3383 - val_accuracy: 0.7750 - val_loss: 0.3964
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8210 - loss: 0.4083 - val_accuracy: 0.7750 - val_loss: 0.3817
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8501 - loss: 0.3892 - val_accuracy: 0.7750 - val_loss: 0.3864
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8405 - loss: 0.4075 - val_accuracy: 0.7750 - val_loss: 0.3910
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8233 - loss: 0.4092 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8385 - loss: 0.3679 - val_accuracy: 0.7750 - val_loss: 0.3753
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8562 - loss: 0.3446 - val_accuracy: 0.7750 - val_loss: 0.3745
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8042 - loss: 0.4288 - val_accuracy: 0.7750 - val_loss: 0.3839
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7911 - loss: 0.4738 - val_accuracy: 0.7750 - val_loss: 0.3975
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8536 - loss: 0.3881 - val_accuracy: 0.7750 - val_loss: 0.3994
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8167 - loss: 0.4224 - val_accuracy: 0.7750 - val_loss: 0.3822
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8302 - loss: 0.3797 - val_accuracy: 0.7750 - val_loss: 0.3811
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8136 - loss: 0.4053 - val_accuracy: 0.7750 - val_loss: 0.3839
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8154 - loss: 0.3926 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8385 - loss: 0.3774 - val_accuracy: 0.7750 - val_loss: 0.3857
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8102 - loss: 0.4022 - val_accuracy: 0.7750 - val_loss: 0.3752
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8405 - loss: 0.3981 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8288 - loss: 0.3818 - val_accuracy: 0.7750 - val_loss: 0.3897
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8488 - loss: 0.3829 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8141 - loss: 0.4227 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8071 - loss: 0.4505 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8305 - loss: 0.4184 - val_accuracy: 0.7750 - val_loss: 0.4018
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8033 - loss: 0.4389 - val_accuracy: 0.7750 - val_loss: 0.3789
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8179 - loss: 0.4147 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8400 - loss: 0.4005 - val_accuracy: 0.7750 - val_loss: 0.3810
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8418 - loss: 0.3622 - val_accuracy: 0.7750 - val_loss: 0.3925
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8092 - loss: 0.4378 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8131 - loss: 0.4153 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8458 - loss: 0.3622 - val_accuracy: 0.8000 - val_loss: 0.3815
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8057 - loss: 0.4479 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8366 - loss: 0.3844 - val_accuracy: 0.7750 - val_loss: 0.3917
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8332 - loss: 0.3445 - val_accuracy: 0.7750 - val_loss: 0.4003
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8162 - loss: 0.4247 - val_accuracy: 0.7750 - val_loss: 0.3812
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8020 - loss: 0.4196 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8258 - loss: 0.4133 - val_accuracy: 0.7750 - val_loss: 0.3733
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8323 - loss: 0.3610 - val_accuracy: 0.7750 - val_loss: 0.4080
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8110 - loss: 0.3943 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8298 - loss: 0.3818 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8058 - loss: 0.4181 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8340 - loss: 0.3725 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8462 - loss: 0.3894 - val_accuracy: 0.7750 - val_loss: 0.3849
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8362 - loss: 0.3950 - val_accuracy: 0.8000 - val_loss: 0.3729
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8240 - loss: 0.4063 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8548 - loss: 0.3637 - val_accuracy: 0.7750 - val_loss: 0.3980
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7997 - loss: 0.4522 - val_accuracy: 0.7750 - val_loss: 0.3728
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7951 - loss: 0.4013 - val_accuracy: 0.7750 - val_loss: 0.3978
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8271 - loss: 0.4101 - val_accuracy: 0.7750 - val_loss: 0.3814
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8293 - loss: 0.4056 - val_accuracy: 0.7750 - val_loss: 0.3789
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8288 - loss: 0.3517 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8718 - loss: 0.3221 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8227 - loss: 0.4234 - val_accuracy: 0.7750 - val_loss: 0.3801
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8237 - loss: 0.4025 - val_accuracy: 0.7750 - val_loss: 0.3761
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7984 - loss: 0.4343 - val_accuracy: 0.7750 - val_loss: 0.3820
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8080 - loss: 0.4099 - val_accuracy: 0.7750 - val_loss: 0.3893

# %%
# Plot the decision region
plot_decision_regions(X, y, clf=model, legend=2);
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step

# %% [markdown]
# #### **Neural Network with Non-Linear Activation in the Hidden Layers**

# %%
# Build a neural network with non-linear activation used in the hidden layers
model = Sequential()

model.add(Dense(128, activation="relu", input_dim=2))
model.add(Dense(128, activation="relu", input_dim=2))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X, y, epochs=500, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.7153 - loss: 0.5477 - val_accuracy: 0.8000 - val_loss: 0.3791
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8234 - loss: 0.3882 - val_accuracy: 0.7750 - val_loss: 0.3740
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8248 - loss: 0.3616 - val_accuracy: 0.8000 - val_loss: 0.3361
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8558 - loss: 0.2895 - val_accuracy: 0.7750 - val_loss: 0.3076
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8102 - loss: 0.3465 - val_accuracy: 0.7750 - val_loss: 0.3128
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8313 - loss: 0.2985 - val_accuracy: 0.7750 - val_loss: 0.3644
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8140 - loss: 0.3048 - val_accuracy: 0.7750 - val_loss: 0.3607
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8231 - loss: 0.3133 - val_accuracy: 0.7750 - val_loss: 0.3697
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8191 - loss: 0.3218 - val_accuracy: 0.8000 - val_loss: 0.3722
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8295 - loss: 0.3044 - val_accuracy: 0.8000 - val_loss: 0.4022
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8459 - loss: 0.2677 - val_accuracy: 0.7750 - val_loss: 0.4027
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8515 - loss: 0.2679 - val_accuracy: 0.8750 - val_loss: 0.3696
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8545 - loss: 0.2865 - val_accuracy: 0.8500 - val_loss: 0.3981
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8545 - loss: 0.2984 - val_accuracy: 0.7750 - val_loss: 0.4513
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7888 - loss: 0.3622 - val_accuracy: 0.8750 - val_loss: 0.3623
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8762 - loss: 0.2753 - val_accuracy: 0.8250 - val_loss: 0.3790
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8420 - loss: 0.3131 - val_accuracy: 0.8000 - val_loss: 0.4256
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8865 - loss: 0.2560 - val_accuracy: 0.8000 - val_loss: 0.4124
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8668 - loss: 0.2510 - val_accuracy: 0.9000 - val_loss: 0.3825
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8326 - loss: 0.2866 - val_accuracy: 0.8750 - val_loss: 0.3831
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8684 - loss: 0.2543 - val_accuracy: 0.7750 - val_loss: 0.4625
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8407 - loss: 0.2946 - val_accuracy: 0.8500 - val_loss: 0.3885
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8636 - loss: 0.2855 - val_accuracy: 0.8500 - val_loss: 0.3711
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8740 - loss: 0.2579 - val_accuracy: 0.8000 - val_loss: 0.4244
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8427 - loss: 0.2863 - val_accuracy: 0.8250 - val_loss: 0.4330
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8362 - loss: 0.2780 - val_accuracy: 0.8750 - val_loss: 0.3741
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8530 - loss: 0.2691 - val_accuracy: 0.8750 - val_loss: 0.3754
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8811 - loss: 0.2723 - val_accuracy: 0.8000 - val_loss: 0.4562
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8910 - loss: 0.2072 - val_accuracy: 0.8250 - val_loss: 0.4363
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8490 - loss: 0.2719 - val_accuracy: 0.8500 - val_loss: 0.3673
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8549 - loss: 0.2727 - val_accuracy: 0.8500 - val_loss: 0.3950
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8512 - loss: 0.2580 - val_accuracy: 0.8750 - val_loss: 0.4512
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8298 - loss: 0.2948 - val_accuracy: 0.8750 - val_loss: 0.4119
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8602 - loss: 0.2742 - val_accuracy: 0.8750 - val_loss: 0.3907
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8757 - loss: 0.2277 - val_accuracy: 0.8750 - val_loss: 0.4299
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8820 - loss: 0.2139 - val_accuracy: 0.8750 - val_loss: 0.4007
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8776 - loss: 0.2422 - val_accuracy: 0.8750 - val_loss: 0.4207
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8597 - loss: 0.2469 - val_accuracy: 0.8750 - val_loss: 0.4149
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8687 - loss: 0.2388 - val_accuracy: 0.8750 - val_loss: 0.4207
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9029 - loss: 0.2153 - val_accuracy: 0.8500 - val_loss: 0.4833
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8635 - loss: 0.2464 - val_accuracy: 0.8750 - val_loss: 0.4097
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9151 - loss: 0.2020 - val_accuracy: 0.8250 - val_loss: 0.4037
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8714 - loss: 0.2307 - val_accuracy: 0.9000 - val_loss: 0.4584
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8255 - loss: 0.3098 - val_accuracy: 0.8750 - val_loss: 0.3976
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8787 - loss: 0.2344 - val_accuracy: 0.8750 - val_loss: 0.4461
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8909 - loss: 0.2290 - val_accuracy: 0.8750 - val_loss: 0.4502
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8735 - loss: 0.2100 - val_accuracy: 0.8750 - val_loss: 0.4548
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9039 - loss: 0.2282 - val_accuracy: 0.8750 - val_loss: 0.4314
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8602 - loss: 0.2242 - val_accuracy: 0.8500 - val_loss: 0.4304
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8852 - loss: 0.2232 - val_accuracy: 0.8750 - val_loss: 0.5284
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8040 - loss: 0.2460 - val_accuracy: 0.8750 - val_loss: 0.4781
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8155 - loss: 0.2882 - val_accuracy: 0.8500 - val_loss: 0.4238
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8121 - loss: 0.2723 - val_accuracy: 0.8750 - val_loss: 0.4785
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8792 - loss: 0.2332 - val_accuracy: 0.8500 - val_loss: 0.5630
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8510 - loss: 0.2609 - val_accuracy: 0.8500 - val_loss: 0.3731
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8609 - loss: 0.2663 - val_accuracy: 0.8750 - val_loss: 0.3726
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8548 - loss: 0.2648 - val_accuracy: 0.8750 - val_loss: 0.4616
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8387 - loss: 0.2546 - val_accuracy: 0.8250 - val_loss: 0.5741
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8398 - loss: 0.2287 - val_accuracy: 0.8750 - val_loss: 0.5009
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8490 - loss: 0.2512 - val_accuracy: 0.8750 - val_loss: 0.4393
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8760 - loss: 0.2263 - val_accuracy: 0.8500 - val_loss: 0.4877
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8618 - loss: 0.2252 - val_accuracy: 0.8750 - val_loss: 0.4475
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8845 - loss: 0.2141 - val_accuracy: 0.8750 - val_loss: 0.5043
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8851 - loss: 0.2050 - val_accuracy: 0.8750 - val_loss: 0.5038
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8565 - loss: 0.2122 - val_accuracy: 0.8750 - val_loss: 0.4817
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8716 - loss: 0.2115 - val_accuracy: 0.8750 - val_loss: 0.4957
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8825 - loss: 0.1901 - val_accuracy: 0.8750 - val_loss: 0.5214
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8677 - loss: 0.2047 - val_accuracy: 0.8750 - val_loss: 0.5288
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8687 - loss: 0.2067 - val_accuracy: 0.8750 - val_loss: 0.5591
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8966 - loss: 0.2058 - val_accuracy: 0.8750 - val_loss: 0.5407
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8655 - loss: 0.2436 - val_accuracy: 0.8500 - val_loss: 0.5961
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8981 - loss: 0.1842 - val_accuracy: 0.8500 - val_loss: 0.5576
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8757 - loss: 0.1946 - val_accuracy: 0.8500 - val_loss: 0.5251
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8926 - loss: 0.1781 - val_accuracy: 0.8000 - val_loss: 0.6583
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8905 - loss: 0.1838 - val_accuracy: 0.8500 - val_loss: 0.5458
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9006 - loss: 0.2048 - val_accuracy: 0.8500 - val_loss: 0.4824
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8918 - loss: 0.1922 - val_accuracy: 0.8500 - val_loss: 0.5826
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8456 - loss: 0.2408 - val_accuracy: 0.8500 - val_loss: 0.6877
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8562 - loss: 0.2278 - val_accuracy: 0.8500 - val_loss: 0.5562
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8965 - loss: 0.1940 - val_accuracy: 0.8750 - val_loss: 0.5776
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8844 - loss: 0.1828 - val_accuracy: 0.8500 - val_loss: 0.6774
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8750 - loss: 0.2032 - val_accuracy: 0.8750 - val_loss: 0.6296
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8952 - loss: 0.1931 - val_accuracy: 0.8750 - val_loss: 0.6092
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8801 - loss: 0.1965 - val_accuracy: 0.8500 - val_loss: 0.6618
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8966 - loss: 0.1914 - val_accuracy: 0.8500 - val_loss: 0.6543
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8796 - loss: 0.2209 - val_accuracy: 0.8500 - val_loss: 0.6470
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9312 - loss: 0.1797 - val_accuracy: 0.8500 - val_loss: 0.7014
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8534 - loss: 0.2220 - val_accuracy: 0.8750 - val_loss: 0.5894
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8800 - loss: 0.1999 - val_accuracy: 0.8500 - val_loss: 0.6767
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8684 - loss: 0.1974 - val_accuracy: 0.8500 - val_loss: 0.7374
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8756 - loss: 0.2168 - val_accuracy: 0.8500 - val_loss: 0.6147
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8636 - loss: 0.2469 - val_accuracy: 0.8500 - val_loss: 0.5836
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8681 - loss: 0.2143 - val_accuracy: 0.8750 - val_loss: 0.5964
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8411 - loss: 0.2413 - val_accuracy: 0.8750 - val_loss: 0.6403
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8887 - loss: 0.1913 - val_accuracy: 0.8500 - val_loss: 0.8117
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8927 - loss: 0.1873 - val_accuracy: 0.8500 - val_loss: 0.6604
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8707 - loss: 0.1968 - val_accuracy: 0.8500 - val_loss: 0.5722
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8924 - loss: 0.1830 - val_accuracy: 0.8500 - val_loss: 0.5265
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8907 - loss: 0.2228 - val_accuracy: 0.8500 - val_loss: 0.5366
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8714 - loss: 0.2315 - val_accuracy: 0.8500 - val_loss: 0.6232
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8972 - loss: 0.2058 - val_accuracy: 0.8500 - val_loss: 0.6329
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8830 - loss: 0.2067 - val_accuracy: 0.8500 - val_loss: 0.6793
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9069 - loss: 0.1650 - val_accuracy: 0.8500 - val_loss: 0.6396
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8905 - loss: 0.1920 - val_accuracy: 0.8750 - val_loss: 0.6154
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8857 - loss: 0.1810 - val_accuracy: 0.8500 - val_loss: 0.6780
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8913 - loss: 0.1723 - val_accuracy: 0.8500 - val_loss: 0.6872
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9067 - loss: 0.2058 - val_accuracy: 0.8500 - val_loss: 0.7121
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8847 - loss: 0.1971 - val_accuracy: 0.8500 - val_loss: 0.7132
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9097 - loss: 0.1792 - val_accuracy: 0.8500 - val_loss: 0.6915
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9147 - loss: 0.1637 - val_accuracy: 0.8500 - val_loss: 0.6988
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8622 - loss: 0.2240 - val_accuracy: 0.8500 - val_loss: 0.7104
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9146 - loss: 0.1773 - val_accuracy: 0.8500 - val_loss: 0.6399
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8746 - loss: 0.2072 - val_accuracy: 0.8750 - val_loss: 0.5972
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8799 - loss: 0.2071 - val_accuracy: 0.8750 - val_loss: 0.6907
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8870 - loss: 0.1839 - val_accuracy: 0.8750 - val_loss: 0.7195
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9022 - loss: 0.1729 - val_accuracy: 0.8750 - val_loss: 0.8465
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8725 - loss: 0.2116 - val_accuracy: 0.8500 - val_loss: 0.7843
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8897 - loss: 0.2197 - val_accuracy: 0.8500 - val_loss: 0.5834
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8683 - loss: 0.2216 - val_accuracy: 0.8500 - val_loss: 0.6228
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9229 - loss: 0.2061 - val_accuracy: 0.8750 - val_loss: 0.7446
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8805 - loss: 0.1866 - val_accuracy: 0.8750 - val_loss: 0.6635
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8827 - loss: 0.1990 - val_accuracy: 0.8500 - val_loss: 0.6604
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8775 - loss: 0.2455 - val_accuracy: 0.8750 - val_loss: 0.7503
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8957 - loss: 0.2106 - val_accuracy: 0.8750 - val_loss: 0.7702
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8978 - loss: 0.2043 - val_accuracy: 0.8750 - val_loss: 0.7835
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9004 - loss: 0.1880 - val_accuracy: 0.8500 - val_loss: 0.7283
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8459 - loss: 0.2217 - val_accuracy: 0.8500 - val_loss: 0.7584
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8857 - loss: 0.2288 - val_accuracy: 0.8500 - val_loss: 0.7497
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8572 - loss: 0.2111 - val_accuracy: 0.8500 - val_loss: 0.7587
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8863 - loss: 0.1918 - val_accuracy: 0.8500 - val_loss: 0.7227
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8801 - loss: 0.1965 - val_accuracy: 0.8750 - val_loss: 0.6712
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8745 - loss: 0.1971 - val_accuracy: 0.8500 - val_loss: 0.7049
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8770 - loss: 0.1970 - val_accuracy: 0.8500 - val_loss: 0.7486
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9003 - loss: 0.1783 - val_accuracy: 0.8500 - val_loss: 0.8068
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8956 - loss: 0.1763 - val_accuracy: 0.8500 - val_loss: 0.7875
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9082 - loss: 0.1655 - val_accuracy: 0.8500 - val_loss: 0.8214
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9261 - loss: 0.1500 - val_accuracy: 0.8500 - val_loss: 0.7997
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9145 - loss: 0.1778 - val_accuracy: 0.8500 - val_loss: 0.7869
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9045 - loss: 0.1813 - val_accuracy: 0.8500 - val_loss: 0.8545
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9034 - loss: 0.1628 - val_accuracy: 0.8500 - val_loss: 0.7727
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1740 - val_accuracy: 0.8500 - val_loss: 0.7539
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8943 - loss: 0.1832 - val_accuracy: 0.8500 - val_loss: 0.8812
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8741 - loss: 0.1940 - val_accuracy: 0.8500 - val_loss: 0.8659
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9099 - loss: 0.1472 - val_accuracy: 0.8500 - val_loss: 0.8440
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9194 - loss: 0.1629 - val_accuracy: 0.8750 - val_loss: 0.8504
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9043 - loss: 0.1614 - val_accuracy: 0.8500 - val_loss: 0.8880
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9227 - loss: 0.1729 - val_accuracy: 0.8500 - val_loss: 0.8656
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8742 - loss: 0.2046 - val_accuracy: 0.8500 - val_loss: 0.8932
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9045 - loss: 0.1770 - val_accuracy: 0.8500 - val_loss: 0.8966
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8924 - loss: 0.1950 - val_accuracy: 0.8500 - val_loss: 0.9459
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9082 - loss: 0.1665 - val_accuracy: 0.8500 - val_loss: 0.9504
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9291 - loss: 0.1566 - val_accuracy: 0.8500 - val_loss: 0.9604
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9187 - loss: 0.1549 - val_accuracy: 0.9000 - val_loss: 0.9643
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8962 - loss: 0.1859 - val_accuracy: 0.8500 - val_loss: 0.9723
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8985 - loss: 0.1920 - val_accuracy: 0.9000 - val_loss: 0.8671
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8933 - loss: 0.1740 - val_accuracy: 0.8750 - val_loss: 0.7165
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8395 - loss: 0.2497 - val_accuracy: 0.8750 - val_loss: 0.9090
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8933 - loss: 0.1918 - val_accuracy: 0.8750 - val_loss: 0.9470
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8566 - loss: 0.2167 - val_accuracy: 0.8750 - val_loss: 0.8459
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8906 - loss: 0.2104 - val_accuracy: 0.8500 - val_loss: 0.8736
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8405 - loss: 0.4309 - val_accuracy: 0.8750 - val_loss: 0.7176
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8895 - loss: 0.1895 - val_accuracy: 0.9000 - val_loss: 0.8591
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8879 - loss: 0.1987 - val_accuracy: 0.8250 - val_loss: 0.9169
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8438 - loss: 0.2584 - val_accuracy: 0.8500 - val_loss: 0.6255
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8559 - loss: 0.2202 - val_accuracy: 0.8500 - val_loss: 0.7250
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8618 - loss: 0.1996 - val_accuracy: 0.8500 - val_loss: 0.7575
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8944 - loss: 0.1772 - val_accuracy: 0.8750 - val_loss: 0.8527
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8628 - loss: 0.2030 - val_accuracy: 0.8750 - val_loss: 0.8133
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8964 - loss: 0.1876 - val_accuracy: 0.8500 - val_loss: 0.7380
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9266 - loss: 0.1688 - val_accuracy: 0.8750 - val_loss: 0.7800
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9046 - loss: 0.1960 - val_accuracy: 0.8500 - val_loss: 0.8229
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8946 - loss: 0.1737 - val_accuracy: 0.8500 - val_loss: 0.8717
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9204 - loss: 0.1752 - val_accuracy: 0.8500 - val_loss: 0.8851
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8777 - loss: 0.1829 - val_accuracy: 0.8500 - val_loss: 0.8572
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9487 - loss: 0.1347 - val_accuracy: 0.8500 - val_loss: 0.8897
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8832 - loss: 0.1731 - val_accuracy: 0.8750 - val_loss: 0.8873
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8899 - loss: 0.1603 - val_accuracy: 0.8500 - val_loss: 0.8701
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9037 - loss: 0.1457 - val_accuracy: 0.8500 - val_loss: 0.9094
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9145 - loss: 0.1594 - val_accuracy: 0.8750 - val_loss: 0.9865
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9161 - loss: 0.1456 - val_accuracy: 0.8500 - val_loss: 0.9011
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8980 - loss: 0.1663 - val_accuracy: 0.8500 - val_loss: 0.8644
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9305 - loss: 0.1440 - val_accuracy: 0.8500 - val_loss: 0.9819
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9055 - loss: 0.1645 - val_accuracy: 0.8500 - val_loss: 0.9623
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9441 - loss: 0.1514 - val_accuracy: 0.8750 - val_loss: 0.9255
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9132 - loss: 0.1735 - val_accuracy: 0.8500 - val_loss: 0.9866
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9122 - loss: 0.1437 - val_accuracy: 0.8500 - val_loss: 0.9425
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9198 - loss: 0.1450 - val_accuracy: 0.8500 - val_loss: 1.0031
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9250 - loss: 0.1605 - val_accuracy: 0.8500 - val_loss: 1.0225
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9057 - loss: 0.1700 - val_accuracy: 0.8500 - val_loss: 0.9830
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9175 - loss: 0.1503 - val_accuracy: 0.8500 - val_loss: 1.0402
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9137 - loss: 0.1509 - val_accuracy: 0.9000 - val_loss: 1.0063
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9224 - loss: 0.1334 - val_accuracy: 0.8750 - val_loss: 1.0329
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9278 - loss: 0.1476 - val_accuracy: 0.8500 - val_loss: 1.1572
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8815 - loss: 0.1893 - val_accuracy: 0.8500 - val_loss: 1.0573
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9023 - loss: 0.1723 - val_accuracy: 0.8500 - val_loss: 0.8937
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9312 - loss: 0.1767 - val_accuracy: 0.8500 - val_loss: 1.0365
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8742 - loss: 0.2538 - val_accuracy: 0.8500 - val_loss: 0.9884
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9042 - loss: 0.1782 - val_accuracy: 0.9000 - val_loss: 0.8173
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8830 - loss: 0.1765 - val_accuracy: 0.8500 - val_loss: 0.9882
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9114 - loss: 0.1817 - val_accuracy: 0.8750 - val_loss: 0.9305
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9058 - loss: 0.1888 - val_accuracy: 0.8750 - val_loss: 0.8540
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8595 - loss: 0.2015 - val_accuracy: 0.8500 - val_loss: 1.0105
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9492 - loss: 0.1667 - val_accuracy: 0.8500 - val_loss: 1.0029
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8839 - loss: 0.1753 - val_accuracy: 0.8500 - val_loss: 0.9462
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9055 - loss: 0.1662 - val_accuracy: 0.8750 - val_loss: 0.9250
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9213 - loss: 0.1473 - val_accuracy: 0.8750 - val_loss: 0.9150
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9135 - loss: 0.1690 - val_accuracy: 0.9000 - val_loss: 0.9352
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9031 - loss: 0.1541 - val_accuracy: 0.8750 - val_loss: 0.9279
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9089 - loss: 0.1630 - val_accuracy: 0.8500 - val_loss: 0.9662
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9115 - loss: 0.1575 - val_accuracy: 0.8500 - val_loss: 1.0116
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9013 - loss: 0.1677 - val_accuracy: 0.8500 - val_loss: 1.0041
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9263 - loss: 0.1573 - val_accuracy: 0.8750 - val_loss: 1.0002
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9092 - loss: 0.1586 - val_accuracy: 0.8500 - val_loss: 1.0250
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9356 - loss: 0.1354 - val_accuracy: 0.8500 - val_loss: 1.0143
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9221 - loss: 0.1343 - val_accuracy: 0.8500 - val_loss: 0.9673
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9151 - loss: 0.1636 - val_accuracy: 0.8750 - val_loss: 1.0272
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9165 - loss: 0.1403 - val_accuracy: 0.8500 - val_loss: 0.9853
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9195 - loss: 0.1468 - val_accuracy: 0.8500 - val_loss: 1.0216
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9148 - loss: 0.1510 - val_accuracy: 0.8500 - val_loss: 1.1281
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9099 - loss: 0.1716 - val_accuracy: 0.8750 - val_loss: 1.0407
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9352 - loss: 0.1326 - val_accuracy: 0.8500 - val_loss: 1.0233
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9075 - loss: 0.1434 - val_accuracy: 0.8500 - val_loss: 1.1094
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9307 - loss: 0.1518 - val_accuracy: 0.8750 - val_loss: 1.1077
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9091 - loss: 0.1708 - val_accuracy: 0.8750 - val_loss: 1.0503
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9122 - loss: 0.1506 - val_accuracy: 0.8500 - val_loss: 1.0881
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9192 - loss: 0.1477 - val_accuracy: 0.8500 - val_loss: 1.0779
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9288 - loss: 0.1525 - val_accuracy: 0.8500 - val_loss: 1.0747
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9174 - loss: 0.1483 - val_accuracy: 0.8500 - val_loss: 1.0941
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9473 - loss: 0.1173 - val_accuracy: 0.8500 - val_loss: 1.1521
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9128 - loss: 0.1491 - val_accuracy: 0.8500 - val_loss: 1.1493
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8992 - loss: 0.1466 - val_accuracy: 0.8750 - val_loss: 1.0000
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9464 - loss: 0.1486 - val_accuracy: 0.8750 - val_loss: 0.9927
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9376 - loss: 0.1585 - val_accuracy: 0.8750 - val_loss: 1.2422
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9036 - loss: 0.1662 - val_accuracy: 0.8750 - val_loss: 1.0768
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8944 - loss: 0.1734 - val_accuracy: 0.8750 - val_loss: 1.0970
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9214 - loss: 0.1382 - val_accuracy: 0.8750 - val_loss: 1.1217
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9169 - loss: 0.1362 - val_accuracy: 0.8750 - val_loss: 1.0682
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9122 - loss: 0.1520 - val_accuracy: 0.8500 - val_loss: 1.0981
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9428 - loss: 0.1221 - val_accuracy: 0.8500 - val_loss: 1.1194
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9293 - loss: 0.1420 - val_accuracy: 0.8500 - val_loss: 1.0822
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9143 - loss: 0.1585 - val_accuracy: 0.8750 - val_loss: 1.1373
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9181 - loss: 0.1549 - val_accuracy: 0.8500 - val_loss: 1.2084
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9199 - loss: 0.1616 - val_accuracy: 0.8500 - val_loss: 1.2018
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9255 - loss: 0.1196 - val_accuracy: 0.8500 - val_loss: 1.1347
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9174 - loss: 0.1302 - val_accuracy: 0.8500 - val_loss: 1.1544
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9262 - loss: 0.1461 - val_accuracy: 0.8500 - val_loss: 1.2311
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9648 - loss: 0.1188 - val_accuracy: 0.8750 - val_loss: 1.2166
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9157 - loss: 0.1449 - val_accuracy: 0.8750 - val_loss: 1.1904
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9049 - loss: 0.1586 - val_accuracy: 0.8500 - val_loss: 1.2169
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9223 - loss: 0.1466 - val_accuracy: 0.8500 - val_loss: 1.2292
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9395 - loss: 0.1459 - val_accuracy: 0.8500 - val_loss: 1.2700
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9178 - loss: 0.1470 - val_accuracy: 0.8750 - val_loss: 1.2787
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9124 - loss: 0.1501 - val_accuracy: 0.8750 - val_loss: 1.1930
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9500 - loss: 0.1294 - val_accuracy: 0.8750 - val_loss: 1.1497
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9088 - loss: 0.1421 - val_accuracy: 0.8750 - val_loss: 1.2039
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8874 - loss: 0.1642 - val_accuracy: 0.8750 - val_loss: 1.2843
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9448 - loss: 0.1182 - val_accuracy: 0.8500 - val_loss: 1.2289
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9419 - loss: 0.1247 - val_accuracy: 0.8750 - val_loss: 1.1960
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9203 - loss: 0.1404 - val_accuracy: 0.8750 - val_loss: 1.2029
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9225 - loss: 0.1546 - val_accuracy: 0.8500 - val_loss: 1.2433
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9491 - loss: 0.1215 - val_accuracy: 0.8500 - val_loss: 1.2035
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9191 - loss: 0.1312 - val_accuracy: 0.8500 - val_loss: 1.2442
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9372 - loss: 0.1093 - val_accuracy: 0.8500 - val_loss: 1.2306
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9475 - loss: 0.1455 - val_accuracy: 0.8500 - val_loss: 1.2552
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9393 - loss: 0.1277 - val_accuracy: 0.8750 - val_loss: 1.1446
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9316 - loss: 0.1482 - val_accuracy: 0.8500 - val_loss: 1.1840
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9226 - loss: 0.1361 - val_accuracy: 0.8500 - val_loss: 1.3098
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9485 - loss: 0.1182 - val_accuracy: 0.8250 - val_loss: 1.2695
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9428 - loss: 0.1251 - val_accuracy: 0.8750 - val_loss: 1.1905
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9622 - loss: 0.1171 - val_accuracy: 0.9000 - val_loss: 1.2016
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9231 - loss: 0.1148 - val_accuracy: 0.8500 - val_loss: 1.2974
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9331 - loss: 0.1360 - val_accuracy: 0.8500 - val_loss: 1.2418
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9340 - loss: 0.1505 - val_accuracy: 0.9000 - val_loss: 1.2174
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9226 - loss: 0.1202 - val_accuracy: 0.8750 - val_loss: 1.2259
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9341 - loss: 0.1230 - val_accuracy: 0.8750 - val_loss: 1.4508
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9233 - loss: 0.1393 - val_accuracy: 0.8750 - val_loss: 1.2132
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9095 - loss: 0.1507 - val_accuracy: 0.9000 - val_loss: 1.1537
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9464 - loss: 0.1337 - val_accuracy: 0.8750 - val_loss: 1.3833
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9383 - loss: 0.1318 - val_accuracy: 0.8750 - val_loss: 1.2703
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9138 - loss: 0.1442 - val_accuracy: 0.9000 - val_loss: 1.2118
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9280 - loss: 0.1419 - val_accuracy: 0.8750 - val_loss: 1.2679
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9478 - loss: 0.1277 - val_accuracy: 0.8750 - val_loss: 1.3767
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9247 - loss: 0.1331 - val_accuracy: 0.9000 - val_loss: 1.2471
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9348 - loss: 0.1229 - val_accuracy: 0.8500 - val_loss: 1.2590
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9460 - loss: 0.1226 - val_accuracy: 0.8750 - val_loss: 1.3060
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9392 - loss: 0.1270 - val_accuracy: 0.8750 - val_loss: 1.4145
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9375 - loss: 0.1205 - val_accuracy: 0.8750 - val_loss: 1.3739
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9380 - loss: 0.1000 - val_accuracy: 0.9000 - val_loss: 1.3086
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9245 - loss: 0.1455 - val_accuracy: 0.8500 - val_loss: 1.3331
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9423 - loss: 0.1059 - val_accuracy: 0.8500 - val_loss: 1.3647
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9392 - loss: 0.1311 - val_accuracy: 0.8500 - val_loss: 1.3429
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9486 - loss: 0.1194 - val_accuracy: 0.8500 - val_loss: 1.3134
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9728 - loss: 0.1118 - val_accuracy: 0.8250 - val_loss: 1.3686
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9283 - loss: 0.1413 - val_accuracy: 0.8750 - val_loss: 1.3932
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9385 - loss: 0.1169 - val_accuracy: 0.8750 - val_loss: 1.4398
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9297 - loss: 0.1226 - val_accuracy: 0.8750 - val_loss: 1.3822
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9378 - loss: 0.1054 - val_accuracy: 0.8750 - val_loss: 1.3273
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9565 - loss: 0.1017 - val_accuracy: 0.8500 - val_loss: 1.4516
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9734 - loss: 0.1045 - val_accuracy: 0.8750 - val_loss: 1.5197
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9289 - loss: 0.1223 - val_accuracy: 0.8750 - val_loss: 1.3926
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9301 - loss: 0.1322 - val_accuracy: 0.9000 - val_loss: 1.2934
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9247 - loss: 0.1427 - val_accuracy: 0.9250 - val_loss: 1.3004
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9267 - loss: 0.1132 - val_accuracy: 0.8750 - val_loss: 1.6194
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9248 - loss: 0.1430 - val_accuracy: 0.9000 - val_loss: 1.4459
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9467 - loss: 0.1142 - val_accuracy: 0.8750 - val_loss: 1.3267
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9480 - loss: 0.1047 - val_accuracy: 0.8500 - val_loss: 1.5168
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8846 - loss: 0.2115 - val_accuracy: 0.8500 - val_loss: 1.4856
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9282 - loss: 0.1581 - val_accuracy: 0.8750 - val_loss: 1.2555
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8951 - loss: 0.2252 - val_accuracy: 0.8500 - val_loss: 1.2315
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9317 - loss: 0.1767 - val_accuracy: 0.7750 - val_loss: 1.7596
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9184 - loss: 0.2749 - val_accuracy: 0.8500 - val_loss: 1.3385
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8667 - loss: 0.2612 - val_accuracy: 0.8750 - val_loss: 1.1331
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8969 - loss: 0.2135 - val_accuracy: 0.9000 - val_loss: 1.0646
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8778 - loss: 0.2665 - val_accuracy: 0.8750 - val_loss: 1.3120
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8773 - loss: 0.2344 - val_accuracy: 0.8750 - val_loss: 1.2510
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9017 - loss: 0.1993 - val_accuracy: 0.9000 - val_loss: 1.0333
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8772 - loss: 0.2523 - val_accuracy: 0.9000 - val_loss: 0.9340
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8683 - loss: 0.2522 - val_accuracy: 0.8750 - val_loss: 1.1210
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8659 - loss: 0.2640 - val_accuracy: 0.9000 - val_loss: 0.9087
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9107 - loss: 0.2034 - val_accuracy: 0.9000 - val_loss: 0.8588
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9191 - loss: 0.1559 - val_accuracy: 0.8750 - val_loss: 0.9542
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8860 - loss: 0.1743 - val_accuracy: 0.8750 - val_loss: 0.9481
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9429 - loss: 0.1428 - val_accuracy: 0.9000 - val_loss: 0.9095
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9312 - loss: 0.1506 - val_accuracy: 0.8750 - val_loss: 0.9606
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9233 - loss: 0.1416 - val_accuracy: 0.8750 - val_loss: 0.9843
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8924 - loss: 0.1512 - val_accuracy: 0.8750 - val_loss: 0.9547
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9088 - loss: 0.1530 - val_accuracy: 0.8750 - val_loss: 0.9724
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9118 - loss: 0.1576 - val_accuracy: 0.8750 - val_loss: 0.9746
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9196 - loss: 0.1481 - val_accuracy: 0.8750 - val_loss: 0.9870
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9286 - loss: 0.1364 - val_accuracy: 0.8750 - val_loss: 0.9472
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9303 - loss: 0.1422 - val_accuracy: 0.9250 - val_loss: 0.9502
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8932 - loss: 0.1512 - val_accuracy: 0.9000 - val_loss: 0.9584
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9031 - loss: 0.1414 - val_accuracy: 0.9000 - val_loss: 1.0181
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9251 - loss: 0.1289 - val_accuracy: 0.9000 - val_loss: 0.9993
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9260 - loss: 0.1382 - val_accuracy: 0.9000 - val_loss: 1.0007
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8931 - loss: 0.1677 - val_accuracy: 0.9000 - val_loss: 1.0149
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9234 - loss: 0.1426 - val_accuracy: 0.9000 - val_loss: 1.0262
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9360 - loss: 0.1190 - val_accuracy: 0.9000 - val_loss: 0.9530
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8970 - loss: 0.1410 - val_accuracy: 0.8750 - val_loss: 0.9956
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8956 - loss: 0.1396 - val_accuracy: 0.9000 - val_loss: 1.0376
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9310 - loss: 0.1279 - val_accuracy: 0.9000 - val_loss: 1.0148
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9424 - loss: 0.1355 - val_accuracy: 0.9000 - val_loss: 1.0064
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9431 - loss: 0.1194 - val_accuracy: 0.9000 - val_loss: 1.0586
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9398 - loss: 0.1195 - val_accuracy: 0.9000 - val_loss: 1.0738
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9122 - loss: 0.1270 - val_accuracy: 0.9000 - val_loss: 1.0778
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9302 - loss: 0.1273 - val_accuracy: 0.9000 - val_loss: 1.0360
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9268 - loss: 0.1228 - val_accuracy: 0.8750 - val_loss: 1.0452
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9302 - loss: 0.1292 - val_accuracy: 0.8750 - val_loss: 1.0869
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9432 - loss: 0.1178 - val_accuracy: 0.8750 - val_loss: 1.0549
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9436 - loss: 0.1129 - val_accuracy: 0.9000 - val_loss: 1.0739
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9659 - loss: 0.1388 - val_accuracy: 0.9000 - val_loss: 1.0915
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9516 - loss: 0.1131 - val_accuracy: 0.8750 - val_loss: 1.1034
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9164 - loss: 0.1198 - val_accuracy: 0.9000 - val_loss: 1.0703
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9400 - loss: 0.1230 - val_accuracy: 0.9000 - val_loss: 1.0704
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9552 - loss: 0.1133 - val_accuracy: 0.9000 - val_loss: 1.1193
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9452 - loss: 0.1305 - val_accuracy: 0.9000 - val_loss: 1.1295
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9625 - loss: 0.0906 - val_accuracy: 0.9250 - val_loss: 1.1054
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9604 - loss: 0.1104 - val_accuracy: 0.9000 - val_loss: 1.1102
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9641 - loss: 0.1281 - val_accuracy: 0.8750 - val_loss: 1.1366
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9345 - loss: 0.1362 - val_accuracy: 0.8750 - val_loss: 1.1397
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9142 - loss: 0.1255 - val_accuracy: 0.8750 - val_loss: 1.1490
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9339 - loss: 0.1244 - val_accuracy: 0.8750 - val_loss: 1.1961
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9273 - loss: 0.1302 - val_accuracy: 0.8750 - val_loss: 1.1645
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9096 - loss: 0.1467 - val_accuracy: 0.9000 - val_loss: 1.1310
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9535 - loss: 0.1164 - val_accuracy: 0.9000 - val_loss: 1.2275
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9575 - loss: 0.1096 - val_accuracy: 0.8750 - val_loss: 1.2623
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9299 - loss: 0.1274 - val_accuracy: 0.9250 - val_loss: 1.1667
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9185 - loss: 0.1312 - val_accuracy: 0.8750 - val_loss: 1.2127
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9371 - loss: 0.1242 - val_accuracy: 0.9000 - val_loss: 1.2142
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9528 - loss: 0.0969 - val_accuracy: 0.8750 - val_loss: 1.2177
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9638 - loss: 0.1154 - val_accuracy: 0.9000 - val_loss: 1.1998
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9230 - loss: 0.1268 - val_accuracy: 0.9000 - val_loss: 1.1961
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9176 - loss: 0.1319 - val_accuracy: 0.8750 - val_loss: 1.2601
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9483 - loss: 0.0996 - val_accuracy: 0.8750 - val_loss: 1.2414
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9306 - loss: 0.1441 - val_accuracy: 0.9000 - val_loss: 1.2195
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9401 - loss: 0.1166 - val_accuracy: 0.8750 - val_loss: 1.2424
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9621 - loss: 0.0979 - val_accuracy: 0.9000 - val_loss: 1.2505
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9551 - loss: 0.0921 - val_accuracy: 0.9000 - val_loss: 1.2560
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9516 - loss: 0.0992 - val_accuracy: 0.9000 - val_loss: 1.3013
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9503 - loss: 0.1189 - val_accuracy: 0.9000 - val_loss: 1.2611
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9534 - loss: 0.1073 - val_accuracy: 0.9000 - val_loss: 1.3129
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9551 - loss: 0.1131 - val_accuracy: 0.9000 - val_loss: 1.2722
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9097 - loss: 0.1309 - val_accuracy: 0.9000 - val_loss: 1.2934
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9547 - loss: 0.1077 - val_accuracy: 0.8750 - val_loss: 1.2952
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9697 - loss: 0.0975 - val_accuracy: 0.8750 - val_loss: 1.3009
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9531 - loss: 0.0880 - val_accuracy: 0.8750 - val_loss: 1.3820
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9681 - loss: 0.0931 - val_accuracy: 0.8750 - val_loss: 1.4056
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9634 - loss: 0.0986 - val_accuracy: 0.9000 - val_loss: 1.2914
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9551 - loss: 0.0960 - val_accuracy: 0.9000 - val_loss: 1.3054
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9535 - loss: 0.1031 - val_accuracy: 0.9000 - val_loss: 1.3299
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9516 - loss: 0.1103 - val_accuracy: 0.8750 - val_loss: 1.3882
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9556 - loss: 0.1093 - val_accuracy: 0.8750 - val_loss: 1.3593
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9631 - loss: 0.0730 - val_accuracy: 0.8750 - val_loss: 1.3017
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9700 - loss: 0.0854 - val_accuracy: 0.9000 - val_loss: 1.3430
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9470 - loss: 0.1339 - val_accuracy: 0.8750 - val_loss: 1.4549
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9135 - loss: 0.1285 - val_accuracy: 0.9000 - val_loss: 1.3668
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9634 - loss: 0.1519 - val_accuracy: 0.9250 - val_loss: 1.1243
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9449 - loss: 0.1387 - val_accuracy: 0.9000 - val_loss: 1.4583
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9578 - loss: 0.0934 - val_accuracy: 0.8500 - val_loss: 1.4076
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9401 - loss: 0.0983 - val_accuracy: 0.9000 - val_loss: 1.2408
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9299 - loss: 0.1055 - val_accuracy: 0.9000 - val_loss: 1.3084
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9543 - loss: 0.1086 - val_accuracy: 0.9000 - val_loss: 1.4146
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9430 - loss: 0.0968 - val_accuracy: 0.8750 - val_loss: 1.4607
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9422 - loss: 0.1089 - val_accuracy: 0.8500 - val_loss: 1.3767
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9663 - loss: 0.0970 - val_accuracy: 0.8750 - val_loss: 1.3527
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9638 - loss: 0.0903 - val_accuracy: 0.8750 - val_loss: 1.3845
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9589 - loss: 0.1093 - val_accuracy: 0.9000 - val_loss: 1.3933
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9539 - loss: 0.1130 - val_accuracy: 0.8500 - val_loss: 1.3912
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9470 - loss: 0.1106 - val_accuracy: 0.8500 - val_loss: 1.4384
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9530 - loss: 0.1043 - val_accuracy: 0.8750 - val_loss: 1.4291
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9481 - loss: 0.1129 - val_accuracy: 0.8750 - val_loss: 1.4200
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9490 - loss: 0.1027 - val_accuracy: 0.9000 - val_loss: 1.4344
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9615 - loss: 0.0876 - val_accuracy: 0.9000 - val_loss: 1.4695
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9677 - loss: 0.0828 - val_accuracy: 0.8750 - val_loss: 1.4672
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9520 - loss: 0.0798 - val_accuracy: 0.9000 - val_loss: 1.4377
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9688 - loss: 0.1016 - val_accuracy: 0.9000 - val_loss: 1.4725
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9569 - loss: 0.0877 - val_accuracy: 0.8500 - val_loss: 1.5612
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9694 - loss: 0.0927 - val_accuracy: 0.9000 - val_loss: 1.3851
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9732 - loss: 0.0875 - val_accuracy: 0.8750 - val_loss: 1.3706
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9333 - loss: 0.1358 - val_accuracy: 0.8500 - val_loss: 1.4334
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9602 - loss: 0.1096 - val_accuracy: 0.8500 - val_loss: 1.4362
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9669 - loss: 0.0789 - val_accuracy: 0.8750 - val_loss: 1.4748
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9646 - loss: 0.0877 - val_accuracy: 0.8750 - val_loss: 1.4159
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9384 - loss: 0.1073 - val_accuracy: 0.9000 - val_loss: 1.3810
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9663 - loss: 0.0827 - val_accuracy: 0.9250 - val_loss: 1.3320
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9832 - loss: 0.0815 - val_accuracy: 0.8500 - val_loss: 1.3499
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9373 - loss: 0.1144 - val_accuracy: 0.8500 - val_loss: 1.4196
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9490 - loss: 0.0831 - val_accuracy: 0.9000 - val_loss: 1.4966
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9546 - loss: 0.1042 - val_accuracy: 0.8500 - val_loss: 1.4183
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9745 - loss: 0.0829 - val_accuracy: 0.9000 - val_loss: 1.3516
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9762 - loss: 0.0852 - val_accuracy: 0.9000 - val_loss: 1.3677
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9654 - loss: 0.0845 - val_accuracy: 0.9000 - val_loss: 1.4828
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9780 - loss: 0.0787 - val_accuracy: 0.8500 - val_loss: 1.4607
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9577 - loss: 0.0852 - val_accuracy: 0.8750 - val_loss: 1.4546
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9621 - loss: 0.0725 - val_accuracy: 0.8500 - val_loss: 1.4681
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9576 - loss: 0.1017 - val_accuracy: 0.9000 - val_loss: 1.4714
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9550 - loss: 0.0810 - val_accuracy: 0.8750 - val_loss: 1.4740
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9754 - loss: 0.0623 - val_accuracy: 0.8750 - val_loss: 1.4624
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9580 - loss: 0.0895 - val_accuracy: 0.8500 - val_loss: 1.4828
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9577 - loss: 0.0748 - val_accuracy: 0.9000 - val_loss: 1.4943
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9668 - loss: 0.0786 - val_accuracy: 0.8750 - val_loss: 1.5265
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9633 - loss: 0.0817 - val_accuracy: 0.9000 - val_loss: 1.4709
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9599 - loss: 0.0767 - val_accuracy: 0.9000 - val_loss: 1.4843
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9619 - loss: 0.0940 - val_accuracy: 0.8750 - val_loss: 1.5424
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9603 - loss: 0.0956 - val_accuracy: 0.8750 - val_loss: 1.5134
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9331 - loss: 0.1135 - val_accuracy: 0.8500 - val_loss: 1.5626
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9739 - loss: 0.0879 - val_accuracy: 0.8750 - val_loss: 1.5945
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9860 - loss: 0.0646 - val_accuracy: 0.8750 - val_loss: 1.6189
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9507 - loss: 0.0943 - val_accuracy: 0.8750 - val_loss: 1.6047
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9723 - loss: 0.0836 - val_accuracy: 0.8750 - val_loss: 1.5744
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9648 - loss: 0.0802 - val_accuracy: 0.8750 - val_loss: 1.5622
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9696 - loss: 0.0739 - val_accuracy: 0.8750 - val_loss: 1.5619
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9628 - loss: 0.0789 - val_accuracy: 0.8500 - val_loss: 1.5370
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9622 - loss: 0.0793 - val_accuracy: 0.8750 - val_loss: 1.5799
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9623 - loss: 0.0873 - val_accuracy: 0.8750 - val_loss: 1.5690
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9706 - loss: 0.0657 - val_accuracy: 0.8750 - val_loss: 1.6160
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9778 - loss: 0.0792 - val_accuracy: 0.8750 - val_loss: 1.6257
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9731 - loss: 0.0686 - val_accuracy: 0.8750 - val_loss: 1.5999
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9668 - loss: 0.0634 - val_accuracy: 0.8750 - val_loss: 1.5791
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9541 - loss: 0.1012 - val_accuracy: 0.8750 - val_loss: 1.6051
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9801 - loss: 0.0718 - val_accuracy: 0.8750 - val_loss: 1.6433
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9676 - loss: 0.0678 - val_accuracy: 0.8500 - val_loss: 1.6439
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9727 - loss: 0.0751 - val_accuracy: 0.8500 - val_loss: 1.6382
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9649 - loss: 0.0710 - val_accuracy: 0.8750 - val_loss: 1.6095
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9660 - loss: 0.0689 - val_accuracy: 0.8750 - val_loss: 1.6126
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9822 - loss: 0.0690 - val_accuracy: 0.8500 - val_loss: 1.5884
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9509 - loss: 0.0827 - val_accuracy: 0.8750 - val_loss: 1.6250
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9826 - loss: 0.0679 - val_accuracy: 0.8500 - val_loss: 1.7769
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9778 - loss: 0.0754 - val_accuracy: 0.8500 - val_loss: 1.6553
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9642 - loss: 0.0616 - val_accuracy: 0.9000 - val_loss: 1.4814
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9826 - loss: 0.0786 - val_accuracy: 0.8750 - val_loss: 1.6928
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9503 - loss: 0.0934 - val_accuracy: 0.8500 - val_loss: 1.6827
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9524 - loss: 0.0782 - val_accuracy: 0.8750 - val_loss: 1.4295
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9680 - loss: 0.1036 - val_accuracy: 0.9000 - val_loss: 1.9987
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9320 - loss: 0.1330 - val_accuracy: 0.8750 - val_loss: 1.5621
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9316 - loss: 0.1214 - val_accuracy: 0.9000 - val_loss: 1.6352
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9457 - loss: 0.1207 - val_accuracy: 0.8750 - val_loss: 2.1090
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9273 - loss: 0.1723 - val_accuracy: 0.8750 - val_loss: 1.7570
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9131 - loss: 0.1919 - val_accuracy: 0.8750 - val_loss: 1.7172
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9020 - loss: 0.2038 - val_accuracy: 0.8250 - val_loss: 1.8437
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9062 - loss: 0.2372 - val_accuracy: 0.8750 - val_loss: 1.7628
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9153 - loss: 0.1658 - val_accuracy: 0.9000 - val_loss: 1.2774
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8729 - loss: 0.2470 - val_accuracy: 0.8750 - val_loss: 1.3810
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8887 - loss: 0.4564 - val_accuracy: 0.9000 - val_loss: 1.2201
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9071 - loss: 0.2284 - val_accuracy: 0.8500 - val_loss: 1.3575
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8964 - loss: 0.1615 - val_accuracy: 0.8750 - val_loss: 1.4091
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9342 - loss: 0.1479 - val_accuracy: 0.8750 - val_loss: 1.2352
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9519 - loss: 0.1360 - val_accuracy: 0.8500 - val_loss: 1.3317
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9510 - loss: 0.1154 - val_accuracy: 0.8250 - val_loss: 1.4120
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9363 - loss: 0.1306 - val_accuracy: 0.8500 - val_loss: 1.2396
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9661 - loss: 0.1000 - val_accuracy: 0.8500 - val_loss: 1.2820
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9826 - loss: 0.0814 - val_accuracy: 0.8500 - val_loss: 1.4541
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9418 - loss: 0.1227 - val_accuracy: 0.8500 - val_loss: 1.2802
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9470 - loss: 0.1535 - val_accuracy: 0.8750 - val_loss: 1.0881
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9504 - loss: 0.1023 - val_accuracy: 0.8250 - val_loss: 1.3157
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9161 - loss: 0.2097 - val_accuracy: 0.8500 - val_loss: 1.1947
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9438 - loss: 0.1514 - val_accuracy: 0.8500 - val_loss: 1.2854
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9552 - loss: 0.1412 - val_accuracy: 0.8250 - val_loss: 1.4396
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9341 - loss: 0.2118 - val_accuracy: 0.8500 - val_loss: 1.2702
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9176 - loss: 0.2462 - val_accuracy: 0.8500 - val_loss: 1.2966

# %%
# Plot the decision region
plot_decision_regions(X, y, clf=model, legend=2);
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step

# %% [markdown]
# #### **Conclusion**
# The first model with linear activations can only separate the data with a straight line, limiting its ability to handle complex patterns.
# The second model with ReLU activations in the hidden layers can create a more flexible and complex decision boundary, leading to better performance on non-linear data distributions.

# %% [markdown]
# ## **Characteristics of an Ideal Activation Function**
# An ideal activation function should have the following characteristics:
#
# 1. **Non-Linear**: Non-linearity allows the network to model complex patterns and relationships in the data, enabling the network to learn and approximate any function, not just linear relationships.
# 2. **Differentiable**: Differentiability ensures that the activation function can be used in gradient-based optimization methods, such as backpropagation.
# 3. **Computationally Inexpensive**: The activation function should be computationally efficient to evaluate, especially for large-scale neural networks, to ensure that training and inference are feasible and fast.
# 4. **Zero-Centered**: A zero-centered activation function outputs values that are centered around zero, helping to ensure that the gradients are balanced and preventing one side of the weights from dominating.
# 5. **Non-Saturating**: Non-saturating activation functions do not suffer from the vanishing gradient problem, where gradients become very small, leading to slow learning or no learning at all. For example, functions like ReLU do not saturate in the positive region, allowing gradients to remain significant, thus helping deep networks to continue learning effectively as the number of layers increases.
# 6. **Smooth**: Smoothness ensures that the activation function doesn’t introduce any abrupt changes in the output, which can help in more stable learning.
# 7. **Monotonic**: A monotonic function ensures that the gradient doesn't change signs, which can simplify the optimization process.

# %% [markdown]
# ## **Different Types of Activation Functions**
# ### **Sigmoid Activation Function**
# The sigmoid activation function is a popular activation function used in neural networks, especially in binary classification tasks. It is defined by the following formula:
# $$\sigma(x) = \frac{1}{1 + e^{-x}}$$
# where $x$ is the input to the neuron.
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*6A3A_rt4YmumHusvTvVTxw.png" width="60%">
#
#
# **Characteristics of the Sigmoid Activation Function:**
#
# 1. **Output Range**: The output of the sigmoid function ranges between 0 and 1. It is useful for models that need to predict probabilities or binary outcomes.
#
# 2. **Non-Linearity**: The sigmoid function is non-linear, allowing the network to capture complex patterns.
#
# 3. **Smooth and Differentiable**: The sigmoid function is smooth and differentiable, making it suitable for gradient-based optimization methods like backpropagation.
#
# 4. **Saturating**: The sigmoid function can saturate, meaning that for very large or very small input values, the output approaches 1 or 0, respectively. This can lead to very small gradients (vanishing gradients), slowing down learning in deep networks.
#
# 5. **Not Zero-Centered**: The output is always positive, which can lead to inefficiencies during training since the gradients will also always be positive or always negative.
#
# 6. **Applications**: Commonly used in the output layer of binary classification models. Also used in the hidden layers of older neural network models, though ReLU and its variants are more commonly used now due to better performance in deeper networks.

# %% [markdown]
# ### **Tanh Activation Function**
# The tanh (hyperbolic tangent) activation function is another widely used activation function in neural networks. It is defined by the following formula:
# $$\text{tanh}(x) = \frac{(e^x - e^{-x})}{e^x + e^{-x}}$$
# where $x$ is the input to the neuron.
#
# <img src="https://qph.cf2.quoracdn.net/main-qimg-f1baf29cfdb09202b18e2179f4f41bfc" width="60%">
#
# **Characteristics of the Tanh Activation Function:**
#
# 1. **Output Range**: The output of the tanh function ranges between $-1$ and $1$. It provides a symmetric output centered around zero, which is an advantage over the sigmoid function.
#
# 2. **Non-Linearity**: Like the sigmoid function, tanh is non-linear, allowing the network to model complex relationships.
#
# 3.  **Smooth and Differentiable**: The tanh function is smooth and differentiable, making it suitable for gradient-based optimization methods like backpropagation.
#
# 4. **Zero-Centered**: Unlike the sigmoid function, tanh is zero-centered, meaning that the output is symmetrically distributed around zero. This helps in balancing the gradients and making learning more efficient.
#
# 5. **Saturating**: Tanh can also saturate, meaning for very large or very small input values, the output approaches 1 or -1. This can lead to the vanishing gradient problem, similar to the sigmoid function.
#
# 6. **Applications**: Often used in hidden layers of neural networks. It was more commonly used before ReLU and its variants became popular due to better performance in deep networks.

# %% [markdown]
# ### **ReLU Activation Function**
# The ReLU (Rectified Linear Unit) activation function is one of the most widely used activation functions in modern neural networks, especially in deep learning. It is defined by the following formula:
# $$\text{ReLU}(x) = \text{max}(0, x)$$
# where $ x $ is the input to the neuron.
#
# <img src="https://wikidocs.net/images/page/164363/Fig_19_deivrelu.jpg" width="60%">
#
# **Characteristics of the ReLU Activation Function:**
#
# 1. **Output Range**: The output of the ReLU function ranges from $0$ to $\infty$. The function outputs zero for any negative input and the input itself for any positive input.
#
# 2. **Non-Linearity**: ReLU is non-linear, allowing the network to model complex patterns and interactions between features.
#
# 3. **Computationally Efficient**: ReLU is simple to compute since it only involves a comparison operation, making it computationally efficient.
#
# 4. **Non-Saturating**: Unlike sigmoid and tanh, ReLU does not saturate for positive inputs, which helps avoid the vanishing gradient problem. This allows for faster learning in deep networks.
#
# 5. **Not Zero-Centered**: The output of ReLU is not zero-centered since it only outputs non-negative values. This can sometimes cause inefficiencies in learning, but these are usually outweighed by the benefits.
#
# 6. **Sparse Activation**: ReLU leads to sparse activation, meaning that in a large network, many neurons will output zero for a given input, which can help with computational efficiency and reducing overfitting.
#
# 7. **Potential Issue (Dying ReLU)**: A potential drawback of ReLU is the "dying ReLU" problem, where neurons can get stuck outputting zero and stop learning. This happens if the weights are updated in such a way that they always produce a negative input for certain neurons.
#
# 8. **Variants**: Variants like Leaky ReLU, Parametric ReLU (PReLU), and ELU have been introduced to address the dying ReLU problem by allowing a small, non-zero gradient for negative inputs.

# %% [markdown]
# ### **Variants of ReLU Activation**
#
# #### **The Dying ReLU Problem**
# The Dying ReLU problem occurs in neural networks when neurons become inactive and only output zero for any input, effectively "dying" and ceasing to contribute to the learning process. This problem arises due to the nature of the ReLU activation function, especially during the training process when weights are updated via backpropagation.
#
# During training, if a large number of neurons in a layer consistently receive negative inputs, these neurons will output zero and their gradients will also be zero. Consequently, these neurons do not contribute to the model's learning since their weights do not get updated (because the gradient of ReLU for $ x \leq 0 $ is zero). If too many neurons "die" this way, it can severely degrade the model's performance.
#
# **Mathematical Formulation:**
#
# - Let $a_i$ be the activation of the $(i)$-th neuron after applying ReLU:
#     $$a_i = \text{ReLU}(z_i) = \max(0, z_i)$$
#     where $z_i = w_i^Tx + b$, with $w_i$ being the weight vector, $x$ the input, and $b_i$ the bias.
#
# - The gradient of the loss function $L$ with respect to input $z_i$ of ReLU is:
#     $$
#     \frac{\partial L}{\partial z_i} = \begin{cases}
#     \frac{\partial L}{\partial a_i} & \text{if } z_i > 0 \\
#     0 & \text{if } z_i \leq 0
#     \end{cases}
#     $$
#
# - If $ z_i \leq 0 $, the gradient becomes zero, leading to no weight update:
#   $$
#   \Delta w_i = -\eta \frac{\partial L}{\partial w_i} = 0
#   $$
#   where $ \eta $ is the learning rate.

# %% [markdown]
# #### 1. **Leaky ReLU:**
# Leaky ReLU is a variant of the Rectified Linear Unit (ReLU) activation function designed to address the Dying ReLU problem. It is defined by the following formula:
# $$
#     \text{Leaky ReLU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     0.01 x & \text{if } x \leq 0
#     \end{cases}
# $$
# where $0.01$ is a small positive constant.
#
# <img src="https://www.researchgate.net/publication/358306930/figure/fig2/AS:1119417702318091@1643901386378/ReLU-activation-function-vs-LeakyReLU-activation-function_W640.jpg" width="60%">
#
# <img src="https://miro.medium.com/v2/resize:fit:2000/1*Ho3rj6FyQTdbQdvOeyACXA.png" width="60%">
#
# **Characteristics:**
# 1. **Non-Linearity**: Like ReLU, Leaky ReLU is non-linear, allowing the network to capture complex patterns.
#
# 2. **Non-Zero Gradient for Negative Inputs**: Unlike standard ReLU, which outputs zero for negative inputs, Leaky ReLU assigns a small, non-zero slope for negative inputs. This ensures that the neuron continues to learn, as the gradient is non-zero for negative inputs.
#
# 3. **Output Range**: The output of Leaky ReLU can range from $-\infty$ to $ \infty $, depending on the input.
#
# 4. **Avoiding the Dying ReLU Problem**: By allowing a small negative slope for negative inputs, Leaky ReLU prevents neurons from getting stuck and "dying" (outputting zero for all inputs).
#
# 5. **Differentiable**: The Leaky ReLU function is differentiable, making it compatible with gradient-based optimization methods like backpropagation.
#
# 6. **Zero-Centered**: Leaky ReLU is not zero-centered, as it outputs positive values for positive inputs and negative values (though small) for negative inputs. However, it still performs well in practice.

# %% [markdown]
# #### 2. **Parametric ReLU (PReLU):**
# Parametric ReLU (PReLU) is a variant of the ReLU (Rectified Linear Unit) activation function designed to improve upon the standard ReLU and its variant, Leaky ReLU, by allowing the slope of the function for negative inputs to be learned during training. This provides more flexibility and adaptability to the network. It is defined by the following formula:
#
# $$
#     \text{PReLU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha_i x & \text{if } x \leq 0
#     \end{cases}
# $$
# where $ \alpha_i $ is a learnable parameter for each neuron, rather than a fixed constant like in Leaky ReLU.
#
# <img src="https://blogs.brain-mentors.com/content/images/2022/06/2813863991-5e720eab30026_articlex.png" width="60%">
#
# **Characteristics:**
# 1. **Learnable Slope**: Unlike Leaky ReLU, where the slope for negative inputs $( \alpha )$ is fixed, PReLU allows this slope to be a parameter that is learned from the data during the training process. This means each neuron can have its own slope $ \alpha_i $ for negative inputs, allowing the network to adapt more effectively to the specific data.
#
# 2. **Non-Linearity**: Like ReLU and Leaky ReLU, PReLU is non-linear, which enables the network to model complex relationships in the data.
#
# 3. **Output Range**: The output of PReLU can range from $-\infty$ to $ \infty $, depending on the input.
#
# 4. **Avoids the Dying ReLU Problem**: Similar to Leaky ReLU, PReLU mitigates the Dying ReLU problem by ensuring that neurons have a non-zero gradient even for negative inputs. However, it improves upon Leaky ReLU by allowing the network to learn the best slope for negative values during training.
#
# 5. **Differentiable**: PReLU is differentiable, making it compatible with gradient-based optimization methods like backpropagation.
#
# 6. **Zero-Centered**: Like ReLU and Leaky ReLU, PReLU is not zero-centered, meaning it can output positive or negative values depending on the input.

# %% [markdown]
# #### 3. **Exponential Linear Unit (ELU):**
# The Exponential Linear Unit (ELU) is an activation function designed to address some of the limitations of the ReLU (Rectified Linear Unit) and its variants. ELU helps to improve the learning dynamics of deep neural networks by introducing a smoother transition from negative to positive values, which can lead to faster learning and better performance. It is defined by the following formula:
# $$
# \text{ELU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha (e^x - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where $ \alpha $ is a hyperparameter that controls the value to which ELU saturates for negative inputs. Typically, $ \alpha $ is set to 1.
#
# <img src="https://i0.wp.com/sefiks.com/wp-content/uploads/2018/01/elu-derivative.png?resize=654%2C422&ssl=1" width="60%">
# <img src="https://tungmphung.com/wp-content/uploads/2020/02/elu_function.png" width="60%">
#
# **Characteristics:**
#
# 1. **Non-Linearity**: ELU is a non-linear activation function, which enables the network to model complex patterns in the data.
#
# 2. **Smoother Transition**: Unlike ReLU, which has a sharp change at $ x = 0 $, ELU provides a smooth and continuous transition between the negative and positive parts of the function. This smoothness can improve the learning dynamics and make optimization easier.
#
# 3. **Negative Values**: ELU allows negative values for inputs less than zero. This negative output helps to push the mean activation closer to zero, which can make the learning process more efficient by reducing bias shifts.
#
# 4. **Avoids the Dying ReLU Problem**: ELU helps mitigate the Dying ReLU problem by allowing negative values. Even for negative inputs, ELU outputs a non-zero value (except for large negative inputs where the output saturates to $-\alpha\$, which helps in maintaining active gradients and continued learning.
#
# 5. **Differentiable**: The ELU function is differentiable, which is essential for backpropagation during training.
#
# 6. **Output Range**: The output of ELU ranges from $-\alpha$ to $ \infty $. For positive inputs, the output is unbounded, similar to ReLU, while for negative inputs, the output saturates at $-\alpha$.
#
# 7. **Parameter $ \alpha $**: The parameter $ \alpha $ controls the saturation point for negative inputs. It is usually set to 1, but it can be tuned depending on the specific application.

# %% [markdown]
# #### 4. **Scaled Exponential Linear Unit (SELU):**
#  The Scaled Exponential Linear Unit (SELU) is an activation function designed to improve the learning dynamics of deep neural networks. It is a self-normalizing activation function, meaning it helps to maintain a mean of zero and unit variance throughout the network, which can significantly enhance training stability and performance. It is defined by the following formula:
#
#  $$
#     \text{SELU}(x) = \lambda \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha (e^x - 1) & \text{if } x \leq 0
#     \end{cases}
#  $$
#
# where $ \alpha $ and $ \lambda $ are predefined constants:
#    - Typically, $ \alpha \approx 1.6733 $
#    - Typically, $ \lambda \approx 1.0507 $
#
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*4IEHWYphW2juRfbCJPQt_w.png" width="60%">
#
# **Characteristics:**
# 1. **Non-Linearity**: SELU is a non-linear activation function, which enables the network to capture complex patterns in the data.
#
# 2. **Self-Normalizing**: The primary advantage of SELU is its self-normalizing property. It helps to maintain zero mean and unit variance throughout the layers of the network, which stabilizes the training process and allows for faster convergence.
#
# 3. **Negative Values**: Similar to ELU, SELU outputs negative values for negative inputs. This negative saturation helps to maintain zero-centered outputs, reducing bias shifts.
#
# 4. **Avoids the Dying ReLU Problem**: By allowing negative values and ensuring a non-zero gradient for all inputs, SELU helps to avoid the Dying ReLU problem, where neurons stop learning due to zero gradients.
#
# 5. **Differentiable**: The SELU function is differentiable, making it compatible with gradient-based optimization methods such as backpropagation.
#
# 6. **Output Range**: The output of SELU ranges from $ \lambda \alpha (e^x - 1) $ for negative inputs to $ \lambda x $ for positive inputs.
